# %%
import billboard as bb
import pandas as pd
import spotipy

# %% [markdown]
# ## Spotify secrets

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# did this work? commenting out so secrets are safe
# print(os.getenv('SPOTIFY_CLIENT_ID'))
# print(os.getenv('SPOTIFY_CLIENT_SECRET'))
# Out:
# True

# %%
client_id  = os.getenv('SPOTIFY_CLIENT_ID')
client_secret  = os.getenv('SPOTIFY_CLIENT_SECRET')

# %% [markdown]
# Billboard 2020 Year End Hot 100 playlist:
# https://open.spotify.com/playlist/1WBljFutuk7uLQtfqfmjWV?si=421973dd4721421f

# %% [markdown]
# ### From Spotipy documentation:

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id,client_secret)
spotify = spotipy.Spotify(auth_manager = auth_manager)

# %%
# Example to check if it's working
# birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

# results = spotify.artist_albums(birdy_uri, album_type='album')
# albums = results['items']
# while results['next']:
#     results = spotify.next(results)
#     albums.extend(results['items'])

# for album in albums:
#     print(album['name'])

# %% [markdown]
# ### Spotify ids gained from billboard_data.ipynb

# %%
hot100_2020_url =  'https://open.spotify.com/playlist/1WBljFutuk7uLQtfqfmjWV?si=421973dd4721421f'
tracks = spotify.playlist_tracks(hot100_2020_url,limit=100)
#i don't want to have to rely on user playlists so will have to come up with another way to get this data

# %% [markdown]
# ### Extracting id or url to run audio_features

# %%
num_1 = pd.DataFrame(pd.DataFrame.from_dict(tracks,orient='columns')['items'][0])['track']['id']
num_1 # this is messy, let's try something else
# Out:
# '0sf12qNH5qcw8qpgymFOqD'

# %%
# audio features for Blinding Lights
spotify.audio_features(tracks=num_1)
# Out:
# [{'danceability': 0.513,
#   'energy': 0.796,
#   'key': 1,
#   'loudness': -4.075,
#   'mode': 1,
#   'speechiness': 0.0629,
#   'acousticness': 0.00147,
#   'instrumentalness': 0.000209,
#   'liveness': 0.0938,
#   'valence': 0.345,
#   'tempo': 171.017,
#   'type': 'audio_features',
#   'id': '0sf12qNH5qcw8qpgymFOqD',
#   'uri': 'spotify:track:0sf12qNH5qcw8qpgymFOqD',
#   'track_href': 'https://api.spotify.com/v1/tracks/0sf12qNH5qcw8qpgymFOqD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0sf12qNH5qcw8qpgymFOqD',
#   'duration_ms': 201573,
#   'time_signature': 4}]

# %%
#audio features can use uri, url, or id with a max of 100
def getList(dict):
    return dict.keys()

print(getList(tracks))
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
type(tracks.get('items')[0])
type(tracks.get('items')[0])
# Out:
# dict

# %%
print(getList(tracks.get('items')[0]))
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
type(tracks.get('items')[0].get('track'))
# Out:
# dict

# %%
print(getList(tracks.get('items')[0].get('track')))
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
tracks.get('items')[0].get('track')['id']
# Out:
# '0sf12qNH5qcw8qpgymFOqD'

# %% [markdown]
# <code>Tracks</code> is a dictionary of lists made up of a dictonary of dictionaries. Writing a function to give us a list of ids which can then be run through <code>audio_features</code>

# %%
ids20 = []

for i in range(0,100):
    id = tracks.get('items')[i].get('track')['id']
    ids20.append(id)

# %%
len(ids20)
# Out:
# 100

# %%
ids20
# Out:
# ['0sf12qNH5qcw8qpgymFOqD',
#  '21jGcNKet2qwijlDFuPiPb',
#  '0nbXyq5TXYPCO7pr3N8S4I',
#  '6WrI0LAC5M1Rw2MnX2ZvEg',
#  '7ytR5pFWmSjzHJIeQkgog4',
#  '3jjujdWJ72nww5eGnfs2E7',
#  '5yY9lUy8nbvjM1Uyo1Uqoc',
#  '2b8fOow8UzyDFAE27YhOZM',
#  '7yFhA2fUsL2oIMWlw5DaHQ',
#  '7qEHsqek33rTcFNT9PFqLf',
#  '3Dv1eDb0MEgF93GpLXlucZ',
#  '5cYFwgA5dHoqR3xGnlr9ew',
#  '2MbdDtCv5LUVjYy9RuGTgC',
#  '1rgnBhdG2JDFTbYkYRZAku',
#  '55CHeLEfn5iJ0IIkgaa4si',
#  '696DnlkuDOXcMAnKlTgXXK',
#  '4umIPjkehX1r7uhmGvXiSV',
#  '3ZCTVFBt2Brf31RLEnCkWJ',
#  '24Yi9hE78yPEbZ4kxyoXAI',
#  '6UelLqGlWMcVH1E5c4H7lY',
#  '2gMXnyrvIjhVBUZwvLZDMP',
#  '4TnjEaWOeW0eKTKIEvJyCa',
#  '2wrJq5XKLnmhRXHIAf9xBa',
#  '4Oun2ylbjFKMPTiaSbbCih',
#  '3QzAOrNlsabgbMwlZt7TAY',
#  '2mt1IqcFyY1zmYZT8Q3xw9',
#  '6wJYhPfqk3KGhHRG76WzOh',
#  '6bnF93Rx87YqUBLSgjiMU8',
#  '6Ozh9Ok6h4Oi1wUSLtBseN',
#  '4l0Mvzj72xxOpRrp6h8nHi',
#  '6KgBpzTuTRPebChN0VTyzV',
#  '127QTOFJsJQp5LbJbu3A1y',
#  '017PF4Q3l4DBUiWoXk4OWT',
#  '5MwynWK9s4hlyKHqhkNn4A',
#  '1xQ6trAsedVPCdbtDAmk0c',
#  '6XHVuErjQ4XNm6nDPVCxVX',
#  '3yOlyBJuViE2YSGn3nVE1K',
#  '0t1kP63rueHleOhQkYSXFY',
#  '1IIKrJVP1C9N7iPtG6eOsK',
#  '07KXEDMj78x68D884wgVEm',
#  '2SAqBLGA283SUiwJ3xOUVI',
#  '598yNsG1JFrGd4n2kMoz7F',
#  '7eJMfftS33KTjuF7lTsMCx',
#  '0TK2YIli7K1leLovkQiNik',
#  '3eekarcy7kvN4yt5ZFzltW',
#  '2Fxmhks0bxGSBdJ92vM42m',
#  '3tjFYV6RSFtuktYl3ZtYcq',
#  '24ySl2hOPGCDcxBxFIqWBu',
#  '0PvFJmanyNQMseIFrU708S',
#  '6cy3ki60hLwimwIje7tALf',
#  '6fWa5CRgy0z30OeGZyMBvD',
#  '5M8goiFYynmNxhueYW6grR',
#  '0lsRatBUs9HNIZAmoGABzk',
#  '2Y0wPrPQBrGhoLn14xRYCG',
#  '5qmq61DAAOUaW8AUo8xKhh',
#  '2kJwzbxV2ppxnQoYw4GLBZ',
#  '6gxKUmycQX7uyMwJcweFjp',
#  '16wAOAZ2OkqoIDN7TpChjR',
#  '7cA3PnUQDlUyBBwpRozQeo',
#  '4TCc369aRPRubv1m8R1TBG',
#  '1Cv1YLb4q0RzL6pybtaMLo',
#  '7FIWs0pqAYbP91WWM0vlTQ',
#  '6Gg1gjgKi2AK4e0qzsR7sd',
#  '5RqR4ZCCKJDcBLIn4sih9l',
#  '1kFpL1itkwkdhO6kcmNJra',
#  '6EDO9iiTtwNv6waLwa1UUq',
#  '0bYg9bo50gSsH3LtXe2SQn',
#  '14GwnOeC9qYEKEA6uOZepa',
#  '10xuH52YSXHWFwCaF1fsDd',
#  '6NhS5LwYbJ6xD7BGvlWRJO',
#  '1000nHvUdawXuUHgBod4Wv',
#  '5Z8HZM6iQMhhqyPcCGY5g9',
#  '0Al3wN3keprGTSgG8NBwjr',
#  '7ge7BHazYbVKi8qyZUX1Bm',
#  '4S2uhQE8L9V6p7rj7SiauJ',
#  '44gRhRi2OhEf7moAUj6MD1',
#  '0DiDStADDVh3SvAsoJAFMk',
#  '1H7KnK26kc1YyellpbINEn',
#  '2u3EyuCqqV31woqGvO9LBz',
#  '4HBZA5flZLE435QTztThqH',
#  '5rZlwNFl01HqLWBQGryKSm',
#  '7lidXGPXPYLNThITAOTlkK',
#  '79s5XnCN4TJKTVMSmOx8Ep',
#  '4nK5YrxbMGZstTLbvj6Gxw',
#  '5Fhe63YOMZsGdB3CgCDuBi',
#  '39Yp9wwQiSRIDOvrVg7mbk',
#  '7qvsl2pYzrsYgPeFBN5jxp',
#  '5f1joOtoMeyppIcJGZQvqJ',
#  '30RZAuEkYeDXvy46Iv6l7E',
#  '1ENdcyhqdylaLsPVgB83qq',
#  '0kPeZAyIhIfeZNrtfjJGDB',
#  '2U5WueTLIK5WJLD7mvDODv',
#  '0nGXi46VcQQ56ZJR428MKS',
#  '48KXAIruJ07kJVCWOGohMV',
#  '62aP9fBQKYKxi7PDXwcUAS',
#  '0eBXyY4SatzpE7opnzgXvz',
#  '0nYvjcSlCgjcwogQAwIwNp',
#  '3sKz6Sd72K0ofPWcJPPk6H',
#  '2rTnVB1bvwxHtaIl4uVu7f',
#  '4cSSL3YafYjM3yjgFO1vJg']

# %%
audio_features = pd.DataFrame.from_dict(spotify.audio_features(tracks=ids20))
audio_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.513   0.796    1    -4.075     1       0.0629       0.00147
# 1         0.695   0.762    0    -3.497     1       0.0395       0.19200
# 2         0.896   0.586   10    -6.687     0       0.0559       0.10400
# 3         0.794   0.793   11    -4.521     0       0.0842       0.01250
# 4         0.746   0.690   11    -7.956     1       0.1640       0.24700
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000209    0.0938    0.345  171.017  audio_features
# 1          0.002440    0.0863    0.553  120.042  audio_features
# 2          0.000000    0.7900    0.642  116.971  audio_features
# 3          0.000000    0.0952    0.677  123.941  audio_features
# 4          0.000000    0.1010    0.497   89.977  audio_features
#
#                        id                                   uri  \
# 0  0sf12qNH5qcw8qpgymFOqD  spotify:track:0sf12qNH5qcw8qpgymFOqD
# 1  21jGcNKet2qwijlDFuPiPb  spotify:track:21jGcNKet2qwijlDFuPiPb
# 2  0nbXyq5TXYPCO7pr3N8S4I  spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# 3  6WrI0LAC5M1Rw2MnX2ZvEg  spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg
# 4  7ytR5pFWmSjzHJIeQkgog4  spotify:track:7ytR5pFWmSjzHJIeQkgog4
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0sf12qNH5qcw...
# 1  https://api.spotify.com/v1/tracks/21jGcNKet2qw...
# 2  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 3  https://api.spotify.com/v1/tracks/6WrI0LAC5M1R...
# 4  https://api.spotify.com/v1/tracks/7ytR5pFWmSjz...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0sf1...       201573
# 1  https://api.spotify.com/v1/audio-analysis/21jG...       215280
# 2  https://api.spotify.com/v1/audio-analysis/0nbX...       196653
# 3  https://api.spotify.com/v1/audio-analysis/6WrI...       183290
# 4  https://api.spotify.com/v1/audio-analysis/7ytR...       181733
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# from pandas_profiling import ProfileReport

# profile = ProfileReport(audio_features)
# profile

# %% [markdown]
# Liveness is a confidence interval that if above a 0.8 signifies it is highly likely a live recorded performance. Since this data set's max is a 0.79, I think that it's safe to say most hits won't be the live version but rather the studio version

# %%
audio_features[audio_features.liveness == audio_features.liveness.max()]['uri'] #listened to check, it's not live
# Out:
# 2    spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# Name: uri, dtype: object

# %% [markdown]
# Columns to drop:
#     * liveness
#     * type
#     * track_href
#     * analysis_url
#     * unsure about instrumentalness

# %%
audio_features = audio_features.drop(columns=['liveness','type','track_href','analysis_url'])

audio_features
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.513   0.796    1    -4.075     1       0.0629       0.00147
# 1          0.695   0.762    0    -3.497     1       0.0395       0.19200
# 2          0.896   0.586   10    -6.687     0       0.0559       0.10400
# 3          0.794   0.793   11    -4.521     0       0.0842       0.01250
# 4          0.746   0.690   11    -7.956     1       0.1640       0.24700
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.621   0.882    6    -5.010     1       0.0459       0.60100
# 96         0.572   0.949    4    -4.865     1       0.0600       0.00165
# 97         0.929   0.667    8    -6.789     0       0.3530       0.01850
# 98         0.827   0.469   10    -9.141     0       0.3410       0.08070
# 99         0.867   0.744    2    -5.171     1       0.2270       0.26800
#
#     instrumentalness  valence    tempo                      id  \
# 0           0.000209    0.345  171.017  0sf12qNH5qcw8qpgymFOqD
# 1           0.002440    0.553  120.042  21jGcNKet2qwijlDFuPiPb
# 2           0.000000    0.642  116.971  0nbXyq5TXYPCO7pr3N8S4I
# 3           0.000000    0.677  123.941  6WrI0LAC5M1Rw2MnX2ZvEg
# 4           0.000000    0.497   89.977  7ytR5pFWmSjzHJIeQkgog4
# ..               ...      ...      ...                     ...
# 95          0.000000    0.574  126.014  0eBXyY4SatzpE7opnzgXvz
# 96          0.000195    0.530  118.974  0nYvjcSlCgjcwogQAwIwNp
# 97          0.000000    0.274  126.998  3sKz6Sd72K0ofPWcJPPk6H
# 98          0.000008    0.196   97.028  2rTnVB1bvwxHtaIl4uVu7f
# 99          0.000000    0.645   84.005  4cSSL3YafYjM3yjgFO1vJg
#
#                                      uri  duration_ms  time_signature
# 0   spotify:track:0sf12qNH5qcw8qpgymFOqD       201573               4
# 1   spotify:track:21jGcNKet2qwijlDFuPiPb       215280               4
# 2   spotify:track:0nbXyq5TXYPCO7pr3N8S4I       196653               4
# 3   spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg       183290               4
# 4   spotify:track:7ytR5pFWmSjzHJIeQkgog4       181733               4
# ..                                   ...          ...             ...
# 95  spotify:track:0eBXyY4SatzpE7opnzgXvz       216573               4
# 96  spotify:track:0nYvjcSlCgjcwogQAwIwNp       194867               4
# 97  spotify:track:3sKz6Sd72K0ofPWcJPPk6H       155168               4
# 98  spotify:track:2rTnVB1bvwxHtaIl4uVu7f       238321               4
# 99  spotify:track:4cSSL3YafYjM3yjgFO1vJg       173288               4
#
# [100 rows x 14 columns]

# %% [markdown]
# # Full dataset of audio features
# I want to know how to make a hit song that lasts, so let's look at the last fifteen year end charts (2006-2020). Due to the limit of Spotify only allowing 100 features pulled at a time, I'll have to pull them in chunks.

# %% [markdown]
# ### Past 15 year's year end Hot 100 spotify urls

# %%
with open('../spotifyids.txt') as f:
    links = f.readlines()

# %%
#let's chunk it into 100s at at ime
def chunks_gen(list,n):
    for i in range(0, len(list), n):
        yield list[i:i+n]

# %%
chunks = list(chunks_gen(links,100))

for i in range(len(chunks)):
    chunks[i] = [x.replace('\n','') for x in chunks[i]]

# %%
chunks
# Out:
# [['0mUyMawtxj1CJ76kn9gIZK',
#   '0k2GOhqsrxDTAbFFSdNJjT',
#   '2gam98EZKrF9XuOkU13ApN',
#   '0vg4WnUWvze6pBOJDTq99k',
#   '3ZFTkvIE7kyPt6Nu3PEa7V',
#   '3U5JVgI2x4rDyHGObzJfNf',
#   '2N5zMZX7YeL1tico8oQxa9',
#   '3kZoay4ANo86ehb6s4RwS9',
#   '0O45fw2L5vsWpdsOdXwNAR',
#   '2RWxrpsFshOBFwRBRstUlQ',
#   '2YegxR5As7BeQuVp2U6pek',
#   '0Aqlt4N5h6rUtKnd09VXpr',
#   '1N62wozuHCvczCkY4QidpP',
#   '7k6IzwMGpxnRghE7YosnXT',
#   '3BxWKCI06eQ5Od8TY2JBeA',
#   '7xYnUQigPoIDAMPVK79NEq',
#   '6brl7bwOHmGFkNw3MBqssT',
#   '05Sgj1Hx03ZXc57gsV1kfX',
#   '30cSNer6TV8x2utjULVeQ5',
#   '4bPQs0PHn4xbipzdPfn6du',
#   '2l57cfmCnOkwNX1tky02n1',
#   '7jRoWfRlLnGYEIEn4t4kbq',
#   '10Nmj3JCNoMeBQ87uw5j8k',
#   '6o3s08kk2fQI37vxGZDrJ1',
#   '7cVmKBwzPsh4Fmb6SplfEm',
#   '4bVuIlGQBMWS7vIhcx8Ae4',
#   '5fVZC9GiM4e8vu99W0Xf6J',
#   '13xxBnXOuiBxVxJI458B0i',
#   '11bD1JtSjlIgKgZG2134DZ',
#   '40LQiUUUKXVGyNs09lHVjW',
#   '5YJtMNWKe55yr49cyJgxva',
#   '7huo2wvrCgRucUsjdSDLQV',
#   '0a7BloCiNzLDD9qSQHh5m7',
#   '1PS1QMdUqOal0ai3Gt7sDQ',
#   '2JpUkUR0OsOlUUfm6iS8ic',
#   '0k6HUzaRHpQ3eEWr1C7Esh',
#   '6k8uthjEbttfWXcGaNTQGD',
#   '3hb2ScEVkGchcAQqrPLP0R',
#   '3f3omU8n47Mqyab5nCaGyT',
#   '4NjR63Up0uMkQBlKvlZd1l',
#   '2QurCbkPO14pjrikPNja0h',
#   '1TsgP2rDfS8VBTckh5BXC0',
#   '7pAT4dOUzjq8Ziap5ShIqC',
#   '7DFnq8FYhHMCylykf6ZCxA',
#   '25sA1vM4BFkTb5cJGWftFo',
#   '2ajhenDRiiAnCHHjsIOHhJ',
#   '0CAJdthKDdRjB2h8YOguN6',
#   '5lDriBxJd22IhOH9zTcFrV',
#   '4Gd9PUEuOTOJtbgd4YxLXM',
#   '1HkVSmzBbdZ5Bzdd00IZgh',
#   '10aWGOqSDBqvNzJ9NeKDbK',
#   '7g7M96UGiA7OR79H86gV4m',
#   '0ADZ5dmXhlfzjMw6lefoPl',
#   '1bPqAXwNiVcM6zjJU1Z4Cd',
#   '0Uc706myy6Th7I6KQ9xA1x',
#   '6MBEjJlXQYXr8dfxDvZuoA',
#   '0qAMjeQFyd1qD0LDiV8gWp',
#   '50UkypyQJbSQLaXHke5Yep',
#   '2OqYarizUUGzSSNHPrDEii',
#   '3UNrtRxBBlWE70SjxnOo02',
#   '4NeOWqHmlrGRuBvsLJC9rL',
#   '0fGh0trRN1xz3s41r7V5ce',
#   '5hF2LnbkpnXCkksMSeWcxZ',
#   '0Eu5SrReZzaJX0NLKI8tQS',
#   '0tYPj0NYa7vjlJaqlRSnJb',
#   '2kQuhkFX7uSVepCD3h29g5',
#   '5qrzhg9Fmu8Amg2uMhHfe5',
#   '2TfSHkHiFO4gRztVIkggkE',
#   '53ETzLQQKFCzykRbqWb1ph',
#   '6giYNaycmjkbf7UmZ6RGtL',
#   '5439qJTu5mVH9aeriwp03u',
#   '3hc7PLcmuZbJGPjhIore1i',
#   '3HVJbdz0V402U5YggQK4Ao',
#   '3aCcDXNXSW4jIpAbRXmWlm',
#   '423EcxblW9F4nnQkqcqMlK',
#   '2Fs18NaCDuluPG1DHGw1XG',
#   '663Karu2rvKLdnY0eo1n3M',
#   '3lec3CzDPAxsZokPph5w87',
#   '5FRIqUXfTazrtRmYEGO4G0',
#   '3rKCDtV8UcF0RytSiXxypc',
#   '4kOTDj4SiZPkW1p96WMDNv',
#   '1tL40tfdtUaSLek4DvDDr3',
#   '0815caqt2Lytro5EIzMufT',
#   '3YfsuymRwUvfCfuoCXBJNJ',
#   '5a4AQWs84xeEyYUd1iC2Pn',
#   '5F7IJrXD6Fa3EmqoYE0gU4',
#   '5imShWWzwqfAJ9gXFpGAQh',
#   '0Ss50OU9tCozI7JIywkv14',
#   '6btyEL6NwUa97Nex9cZFvo',
#   '2lRI7n5b9jlPYsEpRuots6',
#   '3850dYVgOFIXJh5U4BFEWH',
#   '5MYFw4T2gy52pOGBN4EYHS',
#   '0W4NhJhcqKCqEP2GIpDCDq',
#   '5FXOEdfNW7nYQrBWtW49Cl',
#   '1g0oI97rPdYuWDIpkbtQdv',
#   '1Ab6RxeKl3e07zP7Get7CX',
#   '0d28khcov6AiegSCpG5TuT',
#   '0DLOyyQvwPTSDKuhpzMMwA',
#   '3lxFENvLW8nxXAbNfkZ7IJ',
#   '455oIAZ4IjGdcW0lTRpMxx'],
#  ['6RX5iL93VZ5fKmyvNXvF1r',
#   '49FYlytm3dAAraYgpoJZux',
#   '66ZcOcouenzZEnzTJvoFmH',
#   '3Q4WeJmzxuDpzMu9QjQqbM',
#   '1tkMs9wDPknQ3ZHcKDw1ES',
#   '0ZUo4YjG4saFnEJhdWp9Bt',
#   '4RCWB3V8V0dignt99LZ8vH',
#   '4xAk8Lw82G3YoVSOdVAsBx',
#   '2aI21FnmY7TJVKeMaoQZ0t',
#   '4KTtYhxFtFL7mBwnjkKfLm',
#   '7I6DceMT3utDOHjcYCbrr4',
#   '45hOioMDJktr86iKDHC8gr',
#   '1lHXlGlve5Zx8tXLhyjDwM',
#   '07SajbxT3mMTKhbkGjVMBW',
#   '2kQuhkFX7uSVepCD3h29g5',
#   '0AA6zq5ArZ1sSH7VIMi4NK',
#   '234RqTZmnDTnxWlVciXHLD',
#   '2bLqfJjuC5syrsgDsZfGmn',
#   '1D066zixBwqFYqBhKgdPzp',
#   '66TRwr5uJwPt15mfFkzhbi',
#   '0wbDgMuAoy7O7pL3a69uZx',
#   '3pD0f7hSJg2XdQ6udw5Tey',
#   '2Lhdl74nwwVGOE2Gv35QuK',
#   '5fVZC9GiM4e8vu99W0Xf6J',
#   '2mobr1UlKjhxDTOVqng3jw',
#   '4NeOWqHmlrGRuBvsLJC9rL',
#   '4fzsfWzRhPawzqhX8Qt9F3',
#   '3RGyFugqjQjlL8XX0NW8dZ',
#   '1iOJQhxKSJ7dg3Dk03yPnl',
#   '6PBAPjshd2JfEiWpdf3C2a',
#   '1hGy2eLcmC8eKx7qr1tOqx',
#   '1oagRT7LfpVlNJN6FSZDGp',
#   '1RGIjMFMgJxkZHMDXVYzOJ',
#   '6DbqCKweKwVkHgRv1CI53D',
#   '3QnEp4rluCxUwgpXT43jmC',
#   '6n9yCXvLhnYMgJIiIcMu7D',
#   '3Zwu2K0Qa5sT6teCCHPShP',
#   '18lR4BzEs7e3qzc0KVkTpU',
#   '1MBM7CyZbwJpVbbZJnHHRg',
#   '5Y77SQxEr1eiofPeUTPHxM',
#   '0U969xYNlAyfzi8P1TaO7u',
#   '3Cn1FSSTXeQ7hCfrbizrD0',
#   '4JPCdSaqs9dJd7RatFSHww',
#   '0YkJU6TjjwzsVXUPRIO0DB',
#   '5qhlC4Rzals34zxovrPzKp',
#   '40LQiUUUKXVGyNs09lHVjW',
#   '5imShWWzwqfAJ9gXFpGAQh',
#   '4V2F0DZrAXOWq9hkwMMG3x',
#   '44w63XqGr3sATAzOnOySgF',
#   '2a03afRiyAbNAleOByVju4',
#   '4wzjNqjKAKDU82e8uMhzmr',
#   '68Zq7PMcPIQE8ol1x3gAqw',
#   '6oUGAx0vkBcnGzYkvw0ZsA',
#   '1FMHNVeJ9s1x1l1WlaRs2I',
#   '6MnFB3qurhmGs1xdjrz5Bg',
#   '6CFPFnS9EcLs2I0nWqtWci',
#   '2elA6JLRaQ6iB7hxiuTKN4',
#   '5wQnmLuC1W7ATsArWACrgW',
#   '0mYoKqA23wUUj7BTEgNzjg',
#   '11bD1JtSjlIgKgZG2134DZ',
#   '5v4GgrXPMghOnBBLmveLac',
#   '0O45fw2L5vsWpdsOdXwNAR',
#   '4UPcXTh26ilb7owtuyHqNI',
#   '2RqZFOLOnzVmHUX7ZMcaES',
#   '2cm9dQ0TR03TIPorEzffNm',
#   '0rFOs9paloAvEtzwDX1Kmc',
#   '358bOvBiZCS9fRzNYosw6c',
#   '4U1APUMnKkoKlFEcPab212',
#   '24y3tSyLdRbpVsKhQrR2oj',
#   '1pLdjo3lOBbMaoR4ZpybFH',
#   '6TlRNJaezOdzdECnQeRuMM',
#   '6SmPPtaMnfxgz5duA6t9Cu',
#   '3N4DI1vuTSX1tz7fa2NQZw',
#   '0eMdAjfAfGS1AoeXgiyGXP',
#   '6IwKcFdiRQZOWeYNhUiWIv',
#   '56Tl3UgyZTqfZtvFNS31wm',
#   '7beqVxFB2g7DlL09mvfjDv',
#   '0Sc9UwBpChiRKRF8DKvWKZ',
#   '03b1NUHnoavfpLLKcEMfIb',
#   '2L3bghVRLkBbIQzSaEUytZ',
#   '1zyqZONW985Cs4osz9wlsu',
#   '7JSD7rM124eMV8QTR4bAop',
#   '0x1LCpY9Rgeq97VPajm81B',
#   '15JINEqzVMv3SvJTAXAKED',
#   '40Fp6pxcS9l08kL1R50mR4',
#   '36Hwcla06Q5BCr59CL0sBp',
#   '3LGeYNY9aWQuBJovOOowqm',
#   '7zMcNqs55Mxer82bvZFkpg',
#   '4Tn2llBm1g0UlWctmgPL8Z',
#   '2aibwv5hGXSgw7Yru8IYTO',
#   '2JpUkUR0OsOlUUfm6iS8ic',
#   '3wKKkGVn7cVSfgPeYYIiXG',
#   '0ADZ5dmXhlfzjMw6lefoPl',
#   '76dZuMVXjIyLPRLv00skGd',
#   '5iyE2d4U3Vc5cqY9mPTlpy',
#   '10fddGyyeUquZZ2uPTjD7P',
#   '28IEbk5a7twNTbUEvWslUb',
#   '3J58iVk8OXYAGG4YvOKG8u',
#   '0CAfXk7DXMnon4gLudAp7J',
#   '7wZUrN8oemZfsEd1CGkbXE'],
#  ['6IwKcFdiRQZOWeYNhUiWIv',
#   '4P7VFiaZb3xrXoqGwZXC3J',
#   '2cm9dQ0TR03TIPorEzffNm',
#   '5tmambyCorzpRg7ViOO3SN',
#   '4E6cwWJWZw2zWf7VFbH7wf',
#   '5j0McHPthKpOXRr3fBq8M0',
#   '5Lgcn7u07bHuqbOtXkN62u',
#   '3NZJlJemX3mzjf56MqC5ML',
#   '1q51MejmtLKEv8mABG8XRE',
#   '3goSVuTt3fDYDP6kRnFwuL',
#   '1mea3bSkSGXuIRvnydlB5b',
#   '005lwxGU1tms6HGELIcUv9',
#   '6Rb0ptOEjBjPPQUlQtQGbL',
#   '2VOomzT6VavJOGBeySqaMc',
#   '0ByMNEPAPpOR5H69DVrTNy',
#   '1uigwk5hNV84zRd5YQQRTk',
#   '3wKKkGVn7cVSfgPeYYIiXG',
#   '2XbfY2O2v3xwedUJ0J2kkr',
#   '0rFOs9paloAvEtzwDX1Kmc',
#   '5uZGBic80dDBTlTQOuphVo',
#   '1oHClQEgDmmbcEx12Kc5nZ',
#   '0JiY190vktuhSGN6aqJdrt',
#   '28IEbk5a7twNTbUEvWslUb',
#   '50xeLNGKmskmYUSINhqvfa',
#   '1EzrEOXmMH3G43AXT1y7pA',
#   '20ORwCJusz4KS2PbTPVNKo',
#   '4NOZ35Dhucr6UlVyLOtktd',
#   '3Ui2jdyxbZQrZohfM0NOgG',
#   '3AjyOYxBv8bByfBtG5o9dP',
#   '5619Ojc6t9evEEs3B7Drhe',
#   '48s0QHJgmiNsth3WEO6U4M',
#   '6AdLyvisRKHLAwARaZMGr6',
#   '1ixbwbeBi5ufN4noUKmW5a',
#   '1y4eb6hmAvsqlDOl3fx9kk',
#   '3jlbL2OTD5YmIunYzgQTAN',
#   '1Kc5lcuZHLKb3UMWGBNJhi',
#   '22UDw8rSfLbUsaAGTXQ4Z8',
#   '46lIt6GmL0VkkbuUyGDbCs',
#   '15DeqWWQB4dcEWzJg15VrN',
#   '4yHFxB8kzzeuNvoouR8N0N',
#   '6ScJMrlpiLfZUGtWp4QIVt',
#   '0EbnUc05YEKhZRKgbrZWpq',
#   '65D95SmygxGCQGiI64eaZf',
#   '4D2cYdHqk8tu65jUig4OcN',
#   '3JHDtmFdX9kdx9wz0md98U',
#   '7zMcNqs55Mxer82bvZFkpg',
#   '21pySLskKIKrhDziCX5ojQ',
#   '1wva1IlWLDNLgwipUWcmjy',
#   '3MldzywZOH4Uci6bq9noyJ',
#   '0uybt73QFXaLCoxuVf6fhm',
#   '2iXBZ32Fz5VDCLeE0JIdX5',
#   '66TRwr5uJwPt15mfFkzhbi',
#   '0OYcEfskah1egYHjYRvbg1',
#   '4liGjmhCupa7RP9JaQELYx',
#   '34ceTg8ChN5HjrqiIYCn9Q',
#   '7lWF2mVr1KKbVnaT2nSlPo',
#   '6RpiAj9Ofv0Uqp6n2OuRoh',
#   '6wZI4mdT8JwXgkGURnBQiq',
#   '5o4W6yWSJD9e9Ea8YC9WjF',
#   '7iu0WYLdo4yksKf3seaxzI',
#   '7dltD9eEX7X1zk8JJ9BS0e',
#   '3nJjIYchBNkYm7B8XfJf5N',
#   '6TrNRd98WksT9Kkmx9uj6R',
#   '2IBF9lQ9lgVai8LkskI5L7',
#   '5OGkKx8jP0A5KSULEc6XYZ',
#   '5dANgSy7v091dhiPnEXNrf',
#   '6avyV3xlz2UFeiAUZ0SqyT',
#   '4xWMTkwknjh8FzxNrkwLl6',
#   '0x1LCpY9Rgeq97VPajm81B',
#   '49ppqF73rOz5Nyt1paRxIF',
#   '2VEsmoek0sol9MnJFyoG9e',
#   '1kxeWHF9PrCVZHvVskv8lg',
#   '3wkNK8tJZ2stygNJm8RCRD',
#   '4wCD0qOFNRu1Q6O3N6ycm4',
#   '3LN41NUdHkyNqQhi9gExMm',
#   '3Q4WeJmzxuDpzMu9QjQqbM',
#   '14blxrgE0VWAgv5aF2wWmx',
#   '4fixebDZAVToLbUCuEloa2',
#   '7FaJSMXBhSdsxE9Kze7BOa',
#   '33vzOPcd9FRirYGlCu32x4',
#   '2EvwLVrnYbCZEG6Kx5DCRy',
#   '3n5qF6aprwEIjHWuH5jECM',
#   '5rX6C5QVvvZB7XckETNych',
#   '5k3VjTwIsOjQ2woGz3Yx71',
#   '3zcmWxxUA7Em7X3IBqZGUo',
#   '4GXH9A6fzuE0MNtqtzjhLg',
#   '1dObJGQUgJ7tWxJ0byON6W',
#   '31I3Rt1bPa2LrE74DdNizO',
#   '0EHR9OObFtjlhQB8wSt1m7',
#   '5ecZWU5uQOiCVSnPxBZNmT',
#   '7Efs0OIW6zgQyH7ehKZYpN',
#   '5iqk123OZlVkvSiTRiz4p5',
#   '2tVCFmn2zKg2wGXS1TCIIA',
#   '2bLqfJjuC5syrsgDsZfGmn',
#   '3pxCXv0NACYfYnLjFcQW5D',
#   '5Hv1QAbRWrUSUHaT0CmnMS',
#   '2E90KUsor4U2abOJGFKtfx',
#   '11WuptzKtcVfPMYaf5aook',
#   '7xRNsqOQOgWbHV1nbXnfXN',
#   '5R8dQOPq8haW94K7mgERlO'],
#  ['2x7MyWybabEz6Y6wvHuwGE',
#   '4vp2J1l5RD4gMZwGFLfRAu',
#   '7FaJSMXBhSdsxE9Kze7BOa',
#   '3GpbwCm3YxiWDvy29Uo3vP',
#   '1EzrEOXmMH3G43AXT1y7pA',
#   '2ZBNclC5wm4GtiWaeh0DMx',
#   '4EWCNWgDS8707fNSZ1oaA5',
#   '6ihL9TjfRjadfEePzXXyVF',
#   '4P7LVHDbzn7aI6wWRh5AHc',
#   '7IhsLJMqdxoo7YAZjaSMru',
#   '4IoYz8XqqdowINzfRrFnhi',
#   '5VGlqQANWDKJFl0MBG3sg2',
#   '58FUwmyGUqkt53YPUcm7cJ',
#   '08uGhvS5MfBk7crUCpnjva',
#   '13plQdOoWSSXPRUSZc5FuM',
#   '3jlbL2OTD5YmIunYzgQTAN',
#   '2q4rjDy9WhaN3o9MvDbO21',
#   '6cmm1LMvZdB5zsCwX5BjqE',
#   '0V8FYVlBFuXXTIvRnMbZyS',
#   '3QLjDkgLh9AOEHlhQtDuhs',
#   '4Dm32oO01YpIubCHaAtKkN',
#   '4JehYebiI9JE8sR8MisGVb',
#   '1y4eb6hmAvsqlDOl3fx9kk',
#   '0CwYG1UnRmOx8Q1EzElCIL',
#   '7jk7gqyEonmVVYahZN5zhW',
#   '5FEXPoPnzueFJQCPRIrC3c',
#   '5Q0Nhxo0l2bP3pNjpGJwV1',
#   '3bsDo5vjjJI7O8VuytGIrc',
#   '49FYlytm3dAAraYgpoJZux',
#   '6TrNRd98WksT9Kkmx9uj6R',
#   '2oENJa1T33GJ0w8dC167G4',
#   '67T6l4q3zVjC5nZZPXByU8',
#   '0TcJ7QWpggdSg8t0fHThHm',
#   '6fvxos1qSHrIgOkKw4dhWS',
#   '4NpDZPwSXmL0cCTaJuVrCw',
#   '733ncRLzZQT5UtSPg1QmPc',
#   '4fixebDZAVToLbUCuEloa2',
#   '6Rb0ptOEjBjPPQUlQtQGbL',
#   '3IcIIZMMS7UArJJPtEHXG8',
#   '6Hn9Uc1mMNfqChXU3txNke',
#   '7kMfu3KUydmrFVGEAhjtyl',
#   '1kxeWHF9PrCVZHvVskv8lg',
#   '0JiY190vktuhSGN6aqJdrt',
#   '6Rb0ptOEjBjPPQUlQtQGbL',
#   '1ghPzsXXROwbLvBtCnSzFR',
#   '26NX1wPt1TRCH536yocd6i',
#   '1jEtDqwYCKpR0mlrMrrITx',
#   '3tSuRiNgJmMqmYR23dCqnR',
#   '06T10fEzN8ZCcqzQZYA184',
#   '2gnZad0pb6QtUqMLTj2AjI',
#   '7Hqig8kp32q2Ire3ECQvWM',
#   '7rv0UuxMX7CpUUwEE1jVrd',
#   '1mea3bSkSGXuIRvnydlB5b',
#   '1ARJhjuI6TNYZCxYygFQ4F',
#   '1Nme6K1PYAh7p7uygyuRdf',
#   '4shgvM4ClrZeDiflNJwlGd',
#   '34ceTg8ChN5HjrqiIYCn9Q',
#   '3DamFFqW32WihKkTVlwTYQ',
#   '6Wx88Mv6b9ofjKMKkdwOJd',
#   '2igwFfvr1OAGX9SKDCPBwO',
#   '6q4XLE5WeOBWftoc9gTl2P',
#   '4cS2HQ6jK80vqdY9ofpztx',
#   '4UP5HP7IAnNdxD01g1lzQp',
#   '1FKxKGONukVFXWVJxAKmlz',
#   '6klZDCEsQzMELAPyovvpUw',
#   '1le5KVGTF1xWf2aUj7ruLy',
#   '0KlahhzNb98zyN83Vwae0l',
#   '4QJLKU75Rg4558f4LbDBRi',
#   '6c0GmyBsE7mQtrVvxJaWc3',
#   '20X9OeC606XNwEtDBOym5u',
#   '1akgiRM3mN2nxu2AX6ACCW',
#   '2hdy9Wt9qp7M7d0U3ossu2',
#   '4KAzYqfcijCSZa2P3etHoM',
#   '5YL553x8sHderRBDlm3NM3',
#   '2VOomzT6VavJOGBeySqaMc',
#   '64yrDBpcdwEdNY9loyEGbX',
#   '6ATrsVaZT7XjkCynxM8cTS',
#   '3oJJ1dQBxiFYGMQSe2SluG',
#   '3eBnEo9WL34ulBCZlLpUQO',
#   '5Ssv6DaKrW0HczVqx6zXdl',
#   '5vlEg2fT4cFWAqU5QptIpQ',
#   '3XKbdb9GB6u3hsnUklQTav',
#   '3LtwmK1OfN0dGs9jf3qSjn',
#   '3jkdQNkDTxxXtjSO4l0o1H',
#   '6pymOcrCnMuCWdgGVTvUgP',
#   '6HSqyfGnsHYw9MmIpa9zlZ',
#   '6eDApnV9Jdb1nYahOlbbUh',
#   '2YVCkTYJpv5jelYrHYoEG8',
#   '2I5CPUnMIKjEXeg61OI9uV',
#   '72by3Re4C3eVEBXvsUo0zV',
#   '5JnLiuMgRAWoHYOhatFP3s',
#   '2ISojTv3VUnimEOiLddIw4',
#   '4fq2YUONcgrCJ2SPndSeKC',
#   '5myYDbAurm1CW038qd4gL2',
#   '6iBWazas8QsDtBnjlXkrXk',
#   '3yTKrRRkv3tamU33BylIsl',
#   '22NLm3IIR9NLG0cUYtmHMW',
#   '57uX2vR9j9DNiANDYfXw1i',
#   '0HPD5WQqrq7wPWR7P7Dw1i',
#   '11EX5yhxr9Ihl3IN1asrfK'],
#  ['4HlFJV71xXKIGcU3kRyttv',
#   '6tS3XVuOyu10897O3ae7bi',
#   '1bM50INir8voAkVoKuvEUI',
#   '6lV2MSQmRIkycDScNtrBXO',
#   '15JINEqzVMv3SvJTAXAKED',
#   '0SiywuOBRcynK0uKGWdCnn',
#   '1DqdF42leyFIzqNDv9CjId',
#   '1CdqVF1ywD0ZO1zXtB9yWa',
#   '59dLtGBS26x7kc0rHbaPrq',
#   '4nVyHATevhl5RC6Qmoko5H',
#   '3iL2l5gUqyPS6vDwJFgJTR',
#   '5BoIP8Eha5hwmRVURkC2Us',
#   '60jzFy6Nn4M0iD1d94oteF',
#   '7rl7ao5pb9BhvAzPdWStxi',
#   '5jzKL4BDMClWqRguW5qZvh',
#   '7BqBn9nzAq8spo5e7cZ0dJ',
#   '2V4bv1fNWfTcyRJKmej6Sj',
#   '5OiLJ8tjUPFiPX2gVM8fxJ',
#   '2igwFfvr1OAGX9SKDCPBwO',
#   '4356Typ82hUiFAynbLYbPn',
#   '2M9ULmQwTaTGmAdXaXpfz5',
#   '7Ie9W94M7OjPoZVV216Xus',
#   '5vlEg2fT4cFWAqU5QptIpQ',
#   '4MKzCHlZvkwJOQRNkdw4zq',
#   '38xWaVFKaxZlMFvzNff2aW',
#   '6vc2Jq2vaGu8z326kSrw92',
#   '4vp2J1l5RD4gMZwGFLfRAu',
#   '3DamFFqW32WihKkTVlwTYQ',
#   '2fQ6sBFWaLv2Gxos4igHLy',
#   '4BycRneKmOs6MhYG9THsuX',
#   '4lwavw59UjXUPJZtKNdFYp',
#   '6BaxqcoEM9r3LXisTyJjST',
#   '3ZdJffjzJWFimSQyxgGIxN',
#   '1WtTLtofvcjQM3sXSMkDdX',
#   '4DvhkX2ic4zWkQeWMwQ2qf',
#   '2DHc2e5bBn4UzY0ENVFrUl',
#   '4fIWvT19w9PR0VVBuPYpWA',
#   '6ebkx7Q5tTxrCxKq4GYj0Y',
#   '6cmm1LMvZdB5zsCwX5BjqE',
#   '3kMrazSvILsgcwtidZd1Qd',
#   '67T6l4q3zVjC5nZZPXByU8',
#   '0rLAIuJTkrnU812IdCflfn',
#   '2rDwdvBma1O1eLzo29p2cr',
#   '0dBW6ZsW8skfvoRfgeerBF',
#   '2ENexcMEMsYk0rVJigVD3i',
#   '1HfxPaJggVwFsvOtHbVzMz',
#   '3YJkAQNEhmCZGLdmPsu6Ye',
#   '35srNkJVToAzYiZzron1FY',
#   '7lWUJpax919G4JdaFEVmCy',
#   '4AYX69oFP3UOS1CFmV9UfO',
#   '6A5NlmBCsCGbJ27jHQgKV5',
#   '5XRHGXut00SrJUFmcn2lQF',
#   '72phhQtfwZcRweweRxxkmU',
#   '3bMNprrp2JDKZsGbiXpsJl',
#   '4P7LVHDbzn7aI6wWRh5AHc',
#   '0xfpx7AiwgSKEtjotea2L6',
#   '0WCiI0ddWiu5F2kSHgfw5S',
#   '6BdgtqiV3oXNqBikezwdvC',
#   '1fBl642IhJOE5U319Gy2Go',
#   '6KBYk8OFtod7brGuZ3Y67q',
#   '6n1afIfMzcRmDaFneC0c7B',
#   '7Hqig8kp32q2Ire3ECQvWM',
#   '4faiJXyBflUVVOOE9fxbeg',
#   '1w6kG4Rc29m5EherbvpkF5',
#   '5Q0Nhxo0l2bP3pNjpGJwV1',
#   '6wN4nT2qy3MQc098yL3Eu9',
#   '6pymOcrCnMuCWdgGVTvUgP',
#   '45EDI3rk0f4cAMt9f8b56R',
#   '6HSqyfGnsHYw9MmIpa9zlZ',
#   '1MaqkdFNIKPdpQGDzme5ss',
#   '17tDv8WA8IhqE8qzuQn707',
#   '4fq2YUONcgrCJ2SPndSeKC',
#   '5K5LbSTVuKKe1KGMNfBgIW',
#   '1NhPKVLsHhFUHIOZ32QnS2',
#   '079Ey5uxL04AKPQgVQwx5h',
#   '4JOP8ELK6AaeySe7sKe996',
#   '12PNcnMsjsZ3eHm62t8hiy',
#   '6H2wnX7ytNeCKERIVqCwgs',
#   '0JcKdUGNR7zI4jJDLyYXbi',
#   '030OCtLMrljNhp8OWHBWW3',
#   '6IUiqtI8tE49sqGbmtrNd8',
#   '4yXeuHP0l7uM3oXuTdmIWM',
#   '7qje9qxLncMESiPeI27SAn',
#   '1FKxKGONukVFXWVJxAKmlz',
#   '5VGlqQANWDKJFl0MBG3sg2',
#   '1Fo2N5iXRi37maMboaig7O',
#   '1hGy2eLcmC8eKx7qr1tOqx',
#   '1kMuU3TNQvHbqvXCWBodmP',
#   '02eD9ymfJOJOhM97HYp5R9',
#   '4u26EevCNXMhlvE1xFBJwX',
#   '7JIuqL4ZqkpfGKQhYlrirs',
#   '4xInIiKipU1mtUogJ3ZdYr',
#   '3VA8T3rNy5V24AXxNK5u9E',
#   '70NGpcNvhI2hqonWNAETIu',
#   '4ZC8hXXqu2hPcDLw9QTdtQ',
#   '61LtVmmkGr8P9I2tSPvdpf',
#   '1yK9LISg5uBOOW5bT2Wm0i',
#   '5UzU0qw21okODBNUnxptVo',
#   '1c8gk2PeTE04A1pIDH9YMk',
#   '0IkKz2J93C94Ei4BvDop7P'],
#  ['4lCv7b86sLynZbXhfScfm2',
#   '36ux3YuUsGTWPT8fXclS45',
#   '4QNpBfC0zvjKqPJcyqBy9W',
#   '2tJulUYLDKOg9XrtVkMgcJ',
#   '3hlksXnvbKogFdPbpO9vel',
#   '7LcfRTgAVTs5pQGEQgUEzN',
#   '3JA9Jsuxr4xgHXEawAdCp4',
#   '0Oe49j06Bjrxs8PltuVeaW',
#   '7ySUcLPVX7KudhnmNcgY2D',
#   '7w87IxuO7BDcJ3YUqCyMTT',
#   '3avYqdwHKEq8beXbeWCKqJ',
#   '7BqBn9nzAq8spo5e7cZ0dJ',
#   '6Nd5l4UfK8pYiKFg1NBbwE',
#   '1gv4xPanImH17bKZ9rOveR',
#   '3aM7lAYN2kugLRSrZIUXtH',
#   '5SDxsjvegCAJwfQjFmc4WY',
#   '6DkXLzBQT7cwXmTyzAB1DJ',
#   '3hsmbFKT5Cujb5GQjqEU39',
#   '0x3TibRgnSqzkcwrqBd4iX',
#   '4aX4Oycsk1fhHIee1zqsDe',
#   '1zwMYTA5nlNjZxYrvBB2pV',
#   '6OtCIsQZ64Vs1EbzztvAv4',
#   '1ExfPZEiahqhLyajhybFeS',
#   '38iU2jg98IZZEIJPrP7aWD',
#   '4NTWZqvfQTlOMitlVn6tew',
#   '0JNdS1n0ifOP25XvhwAMgM',
#   '3LUWWox8YYykohBbHUrrxd',
#   '5A6OHHy73AR5tLxgTc98zz',
#   '2i0AUcEnsDm3dsqLrFWUCq',
#   '3pYDZTJM2tVBUhIRifWVzI',
#   '5zpDHEU12zATwLGvozxPw2',
#   '4u26EevCNXMhlvE1xFBJwX',
#   '0qOnSQQF0yzuPWsXrQ9paz',
#   '7vWFaMq63AwkFDhS2OAg5u',
#   '6Iocm6VMu6bVNYwiDoyQFW',
#   '3rfhI32Il2hVRKDkuGeeen',
#   '2ENexcMEMsYk0rVJigVD3i',
#   '0z5ZPs57J2KERwM1tBM2GF',
#   '2OXidlnDThZR3zf36k6DVL',
#   '2qYsSHsYkihWx043HVJQRV',
#   '1DqdF42leyFIzqNDv9CjId',
#   '03tqyYWC9Um2ZqU0ZN849H',
#   '5cCAZS9VhLGEDV4NCfieeg',
#   '608a1wIsSd5KzMEqm1O7w3',
#   '16Of7eeW44kt0a1M0nitHM',
#   '2QtxlzvSBONjs1bDC34ixs',
#   '1ia019RqDK2o4QiANR1Dyn',
#   '70ATm56tH7OrQ1zurYssz0',
#   '3ZdJffjzJWFimSQyxgGIxN',
#   '4Cv5dkUBqepa0siwGREihD',
#   '5RfBhOGNbbXT5LiIvbHLhN',
#   '0HZhYMZOcUzZKSFwPOti6m',
#   '53DB6LJV9B8sz0p1s6tlGS',
#   '0obBFrPYkSoBJbvHfUIhkv',
#   '45sDIKapDyxPl307QpEAwl',
#   '22L7bfCiAkJo5xGSQgmiIO',
#   '7Dyq1bhhjknLKEGg4k5NLr',
#   '0aBKFfdyOD1Ttvgv0cfjjJ',
#   '2z4U9d5OAA4YLNXoCgioxo',
#   '61HQWI1Woxup7CnGwVUsdI',
#   '4AYX69oFP3UOS1CFmV9UfO',
#   '4356Typ82hUiFAynbLYbPn',
#   '09ZcYBGFX16X8GMDrvqQwt',
#   '0gY2iq0xJPRoIB1PScKSw4',
#   '7CZiLgkiVHhFcDkI2Y4lZ4',
#   '6qn9YLKt13AGvpq9jfO8py',
#   '2Adn2LNgkHMH5TelQVAu4n',
#   '6rkAY9rk1NTFB94QxG3LJR',
#   '4DvhkX2ic4zWkQeWMwQ2qf',
#   '1tAutlhI9FwnKn7fVgmd5P',
#   '3DrjZArsPsoqbLzUZZV1Id',
#   '5jzKL4BDMClWqRguW5qZvh',
#   '1nVLAEzhBXMJLR5zAl90Nl',
#   '46MDLc0Yip6xCMSsdePOAU',
#   '079Ey5uxL04AKPQgVQwx5h',
#   '3ts6xK5GzfMAAriT9AIBmP',
#   '0b2IVjeD268pYd7VUhmtKI',
#   '0yD66650JxhqKbW76C2qCo',
#   '10yIZv28DUZPHkdqJfzEZs',
#   '1pbHy9VBpSyZh56xuujZz0',
#   '4dWjQ3wEfW6KPaaxCoaPH4',
#   '6LxSe8YmdPxy095Ux6znaQ',
#   '3lBRNqXjPp2j3JMTCXDTNO',
#   '1r3myKmjWoOqRip99CmSj1',
#   '63rbP24OzfaQCJjsHWZXnY',
#   '3dhvQUA0NyrAea4vQ7X6Gn',
#   '7B6m8tHAYZsOKOKMU5SR2n',
#   '6jg5SRvdGxvJ0DzNV0UqEK',
#   '0JXXNGljqupsJaZsgSbMZV',
#   '5mvKuE9Lf9ARVXVXA32kK9',
#   '0w9LJae3sVlZlH2CnxTInF',
#   '3FFcZZq3Z3EJrhUecwcMdG',
#   '2TAcwD5KcV9uY3O1tLGV15',
#   '1fBl642IhJOE5U319Gy2Go',
#   '1t2hJFgJyUPD2crOafMUEk',
#   '23hDnIFoFlVTDA6y8YrJoR',
#   '70tFuqBcduJv15bEnOPRTh',
#   '4wCmqSrbyCgxEXROQE6vtV',
#   '3TGRqZ0a2l1LRblBkJoaDx',
#   '7a86XRg84qjasly9f6bPSD'],
#  ['1LmN9SSHISbtp9LoaR5ZVJ',
#   '7gUpO6td4OOnu0Lf9vhcIV',
#   '3AGOgQzp0YcPH41u9p7dOp',
#   '6D60klaHqbCl9ySc8VcRss',
#   '6qn9YLKt13AGvpq9jfO8py',
#   '1oHNvJVbFkexQc0BpQp7Y4',
#   '4cluDES4hQEUhmXj6TXkSo',
#   '1NpW5kyvO4XrNJ3rnfcNy3',
#   '73CMRj62VK8nUS4ezD2wvi',
#   '0obBFrPYkSoBJbvHfUIhkv',
#   '6t6oULCRS6hnI7rm0h5gwl',
#   '5JLv62qFIS1DR3zGEcApRt',
#   '2LEF1A8DOZ9wRYikWgVlZ8',
#   '3bC1ahPIYt1btJzSSEyyrF',
#   '4XNrMwGx1SqP01sqkGTDmo',
#   '0KAiuUOrLTIkzkpfpn9jb9',
#   '4Kz4RdRCceaA9VgTqBhBfa',
#   '5WQQIDU3HRaMyPkob8mpFb',
#   '2iUmqdfGZcHIhS3b9E9EWq',
#   '124NFj84ppZ5pAxTuVQYCQ',
#   '0lHAMNU8RGiIObScrsRgmP',
#   '53QF56cjZA9RTuuMZDrSA6',
#   '0RUGuh2uSNFJpGMSsD1F5C',
#   '4qikXelSRKvoCqFcHLB2H2',
#   '3UGIZ8qcrMTwzLbx6Kttqt',
#   '0IkKz2J93C94Ei4BvDop7P',
#   '4sK96UnGx3NjBaqvfTG2dm',
#   '1nZzRJbFvCEct3uzu04ZoL',
#   '1KLI5v1PADHinOS7NhiQJ3',
#   '0VwNdo84DaVYLIkbVO86ND',
#   '0pwYLVXVknPSGUQb39cePC',
#   '6JOlNkT0QdHeZB0wPbI9IR',
#   '7LcfRTgAVTs5pQGEQgUEzN',
#   '4k80K0b6KZ2QjAYkXON7q6',
#   '3DamFFqW32WihKkTVlwTYQ',
#   '3sP3c86WFjOzHHnbhhZcLA',
#   '4Li2WHPkuyCdtmokzW2007',
#   '3oL3XRtkP1WVbMxf7dtTdu',
#   '1gihuPhrLraKYrJMAEONyc',
#   '1zwMYTA5nlNjZxYrvBB2pV',
#   '12eMQUn2GzfsfsQLH53M19',
#   '0srwKuJPH8yBzzFUJMBQM2',
#   '6MAdEUilV2p9RQUqE5bMAK',
#   '03UrZgTINDqvnUMbbIMhql',
#   '62zFEHfAYl5kdHYOivj4BC',
#   '4rsW3WCZBGwhHfJWuHRwyT',
#   '1tAutlhI9FwnKn7fVgmd5P',
#   '3bfqkspKABT4pPicm6wC9F',
#   '0p1BcEcYVO3uk4KDf3gzkY',
#   '3b7CDTKB0SRTmQ6ytYi5vZ',
#   '6j9iyrrmqWlQZ5SD1hSTaq',
#   '6E11E0lT5Zy7yb6iT3y8DN',
#   '18VfHIPaCo0s6FTi1Fnp6T',
#   '3ZAMtgYJFoHwJjFkhkXqKr',
#   '05ZACkzW8YbRq3eFgIfSNB',
#   '4urcG6Nfubqsuqy3juMjBi',
#   '6j7hih15xG2cdYwIJnQXsq',
#   '0qOnSQQF0yzuPWsXrQ9paz',
#   '3eQlGeyuSibgAGPEJugaDW',
#   '2wAJTrFhCnQyNSD3oUgTZO',
#   '2A73XBDBQgmdXO8VsXPWIs',
#   '4wkQmYpAaMe41Rc3sYZ7Vz',
#   '20DfkHC5grnKNJCzZQB6KC',
#   '2Gy3XMLbBxACZ4tXdFRGr7',
#   '0W4Kpfp1w2xkY3PrV714B7',
#   '6nek1Nin9q48AVZcWs9e9D',
#   '0vFMQi8ZnOM2y8cuReZTZ2',
#   '1c8gk2PeTE04A1pIDH9YMk',
#   '5pyVqlqThcxI7tPDjHIzPh',
#   '1ms5tNNdPouTtcD2oVF9Oz',
#   '4kte3OcW800TPvOVgrLLj8',
#   '0LohatbcUXRauoeMlR1jnS',
#   '6BCrbWBpb8d6KWmEqZ41tr',
#   '25CA8QVJQrh5R05UUCaODM',
#   '3m8CQnnfJJp4eQMWWl3zay',
#   '4EfN6bixdOOgoLYR5C4cWo',
#   '0RzT9tBLcQhofW2TNiHP9B',
#   '2NniAhAtkRACaMeYt48xlD',
#   '4YKAOXyqkKZ5gOZR0AmVMN',
#   '079Ey5uxL04AKPQgVQwx5h',
#   '1RMRkCn07y2xtBip9DzwmC',
#   '7EQGXaVSyEDsCWKmUcfpLk',
#   '42EMFjvFtOki8MA0JNZqVK',
#   '6lanRgr6wXibZr8KgzXxBl',
#   '2o5mwv7hvas1jdUg14Nihv',
#   '3Yt9lRtS5V4nbJnwcgFgvC',
#   '0mtPNQl5vePVwiI9Vykp7L',
#   '6BtmXhTJMM9sBTHeYYASGz',
#   '1POAx4NMLOBPVKZUSsBh92',
#   '0cV4xwUA4ue2deqq4CZFko',
#   '1z9kQ14XBSN0r2v6fx4IdG',
#   '6E9V9TRlVOLjenGjHemzEH',
#   '6Ymvlzom4TQeoKqAWsZRD8',
#   '25cUhiAod71TIQSNicOaW3',
#   '17X2tSzibD9n9QRjdExcWT',
#   '0Nu9WA8kEbBWEsay2s8Q0U',
#   '7oVEtyuv9NBmnytsCIsY5I',
#   '0CokSRCu5hZgPxcZBaEzVE',
#   '0n4bITAu0Y0nigrz3MFJMb',
#   '4G8gkOterJn0Ywt6uhqbhp'],
#  ['01XFgRZfZI7oBagNf1Loml',
#   '0CokSRCu5hZgPxcZBaEzVE',
#   '4rHZZAmHpZrA3iH5zx8frV',
#   '1mKXFLRA179hdOWQBwUk9e',
#   '0nJW01T7XtvILxQgC5J7Wh',
#   '0i5el041vd6nxrGEU8QRxy',
#   '6F5c58TMEs1byxUstkzVeM',
#   '3w3y8KPTfNeOKPiqUTakBh',
#   '0W4Kpfp1w2xkY3PrV714B7',
#   '789CxjEOtO76BVD1A9yJQH',
#   '2Foc5Q5nqNiosCNqttzHof',
#   '2dLLR6qlu5UJ5gk0dKz0h3',
#   '72jCZdH0Lhg93z6Z4hBjgj',
#   '2y4lAQpi5VTNLu2ldeTdUH',
#   '2vwlzO0Qp8kfEtzTsCXfyE',
#   '0nrRP2bk19rLc0orkWPQk2',
#   '6vt0I1cw1YmAIKDJvHVIM5',
#   '6mH3qVIeOsnQIAho5eWwhH',
#   '37jTPJgwCCmIGMPB45jrPV',
#   '6SwqPZs0XuSnyqkbnkkAjQ',
#   '60wwxj6Dd9NJlirf84wr2c',
#   '7ueP5u2qkdZbIPN2YA6LR0',
#   '2V65y3PX4DkRhy1djlxd9p',
#   '1z9kQ14XBSN0r2v6fx4IdG',
#   '6HZ9VeI5IRFCNQLXhpF4bq',
#   '6Z8R6UsFuGXGtiIxiD8ISb',
#   '55h7vJchibLdUkxdlX3fK7',
#   '06EL94D0TA27Ik0Ke5usbj',
#   '5DI9jxTHrEiFAhStG7VA8E',
#   '6LoQHIo74tOzQ8EsLEkhgF',
#   '2aSC2xhRxOLiiZZVjhbylH',
#   '6TwfdLbaxTKzQi3AgsZNzx',
#   '0Hf4aIJpsN4Os2f0y0VqWl',
#   '5ka2ajep9OAvU5Sgduhiex',
#   '4XNrMwGx1SqP01sqkGTDmo',
#   '7tGlzXJv6GD5e5qlu5YmDg',
#   '7s0lDK7y3XLmI7tcsRAbW0',
#   '4X5f3vT8MRuXF68pfjNte5',
#   '190jyVPHYjAqEaOGmMzdyk',
#   '0CokSRCu5hZgPxcZBaEzVE',
#   '24LS4lQShWyixJ0ZrJXfJ5',
#   '2nMeu6UenVvwUktBCpLMK9',
#   '4rsW3WCZBGwhHfJWuHRwyT',
#   '6BtmXhTJMM9sBTHeYYASGz',
#   '2uwnP6tZVVmTovzX5ELooy',
#   '4esOae7i4rqTbAu9o5Pxco',
#   '1V6gIisPpYqgFeWbMLI0bA',
#   '0HnaqUxvHP5LaWdmWwJpiS',
#   '6JnufVNLIO5F5Lk4sEVLeI',
#   '1jF7IL57ayN4Ity3jQqGu0',
#   '3xdjjKMcMOFgo1eQrfbogM',
#   '03UrZgTINDqvnUMbbIMhql',
#   '05SBRd4fXgn8FX7bf8BCAE',
#   '7EQGXaVSyEDsCWKmUcfpLk',
#   '6t6oULCRS6hnI7rm0h5gwl',
#   '5yhKaacMZGRo4s6evJx9vk',
#   '39FwE8edwuyiaa4PrGBkP7',
#   '5L79aNYCTKiZq7vaOElXYj',
#   '3LlAyCYU26dvFZBDUIMb7a',
#   '6sy3LkhNFjJWlaeSMNwQ62',
#   '4bZd0nRuX8HyjeXAUBczvm',
#   '2ihCaVdNZmnHZWt0fvAM7B',
#   '5FljCWR0cys07PQ9277GTz',
#   '6Xk7PnitV9jCRorWt2LiVZ',
#   '5qxPabNDnJQ551Tf4v6k3j',
#   '6GBUsjHfZuweYf5lQEz6mP',
#   '76VtA90NKurNqaQpV126Ue',
#   '3bIxTsfeNMO7Nt2J3EUKrA',
#   '4FkgULes13bk2eHrsJg4q9',
#   '5HOpkTTVcmZHnthgyxrIL8',
#   '5T7ZFtCcOgkpjxcuaeZbw0',
#   '1VdZ0vKfR5jneCmWIUAMxK',
#   '7gpy7sfWPNuOKmUNs3XQYE',
#   '4sSUYUpB5epI7xTi5wfpOI',
#   '5HGibWoxnkYSkl6mHmAlOE',
#   '6REbwUNlppTfcnV4d4ZoZi',
#   '5yIiXdLRE85OBiQmCaUenq',
#   '6s8nHXTJVqFjXE4yVZPDHR',
#   '0rFZaQ4crlGAzuCjWCQ2xu',
#   '25cUhiAod71TIQSNicOaW3',
#   '1X1DWw2pcNZ8zSub3uhlNz',
#   '4kte3OcW800TPvOVgrLLj8',
#   '0HFrCOmhCYXlv4NdEwRAuj',
#   '1Xsxp1SEOxuMzjrFZhtw8u',
#   '2mXsZsJBThTaJXbNcg5QD4',
#   '6GsAD8PgHxmEuIPTG8GP3M',
#   '0uFvvXbmGIXlf5ZgtHyYpf',
#   '0p1BcEcYVO3uk4KDf3gzkY',
#   '4kY7rYtE4OQkJNq22OIYRI',
#   '6s9ICeczYOfbHHIaSMq9jd',
#   '6Uy6K3KdmUdAfelUp0SeXn',
#   '0JmiBCpWc1IAc0et7Xm7FL',
#   '6enPOmd3vSFpI4jjms8kXN',
#   '6J5sxraPPZ4b0CVOGAgpXj',
#   '1yjY7rpaAQvKwpdUliHx0d',
#   '60nZcImufyMA1MKQY3dcCH',
#   '5jrdCoLpJSvHHorevXBATy',
#   '3U4isOIWM3VvDubwSI3y7a',
#   '3oiMJQAWVaxSubJ7b2VUtX',
#   '6sy3LkhNFjJWlaeSMNwQ62'],
#  ['6g6A7qNhTfUgOSH7ROOxTD',
#   '6RtPijgfPKROxEzTHNRiDp',
#   '5jE48hhRu8E6zBDPRSkEq7',
#   '7vS3Y0IKjde7Xg85LWIEdP',
#   '5Nm9ERjJZ5oyfXZTECKmRt',
#   '3cHyrEgdyYRjgJKSOiOtcS',
#   '3gbBpTdY8lnQwqxNCcf795',
#   '5xTtaWoae3wi06K5WfVUUH',
#   '5SehvGGC53A7SZKCLXQcyt',
#   '0lYBSQXN6rCTvUZvg9S0lU',
#   '48RrDBpOSSl1aLVCalGl5C',
#   '6Vc5wAMmXdKIAM7WUoEb7N',
#   '3G6hD9B2ZHOsgf4WfNu7X1',
#   '0JmiBCpWc1IAc0et7Xm7FL',
#   '2dLLR6qlu5UJ5gk0dKz0h3',
#   '0qcr5FMsEO85NAQjrlDRKo',
#   '0nrRP2bk19rLc0orkWPQk2',
#   '3LlAyCYU26dvFZBDUIMb7a',
#   '4nVBt6MZDDP6tRVdQTgxJg',
#   '2s1sdSqGcKxpPr5lCl7jAV',
#   '7pNC5ZIKtwUK0ReSpM3P9f',
#   '0puf9yIluy9W0vpMEUoAnN',
#   '1DunhgeZSEgWiIYbHqXl0c',
#   '4gbVRS8gloEluzf0GzDOFc',
#   '5BrTUo0xP1wKXLJWUaGFtk',
#   '5Hroj5K7vLpIG4FNCRIjbP',
#   '14OxJlLdcHNpgsm4DRwDOB',
#   '6YUTL4dYpB9xZO5qExPf05',
#   '0Y1MWB026LYxGvhq4EcMiC',
#   '6jG2YzhxptolDzLHTGLt7S',
#   '794F99D5BQHS5ZGRXAs7I5',
#   '12KUFSHFgT0XCoiSlvdQi4',
#   '32lm3769IRfcnrQV11LO4E',
#   '0xMd5bcWTbyXS7wPrBtZA6',
#   '2sLwPnIP3CUVmIuHranJZU',
#   '3s4U7OHV7gnj42VV72eSZ6',
#   '0Dc7J9VPV4eOInoxUiZrsL',
#   '4q6dqyGM25sKFU8nYAGRe4',
#   '2vwlzO0Qp8kfEtzTsCXfyE',
#   '3nB82yGjtbQFSU0JLAwLRH',
#   '6F5c58TMEs1byxUstkzVeM',
#   '1j8z4TTjJ1YOdoFEDwJTQa',
#   '2stPxcgjdSImK7Gizl8ZUN',
#   '2TR7A4ulH9R1PNwMyd8o8U',
#   '6FE2iI43OZnszFLuLtvvmg',
#   '3qZBKfaalskxRCjP3GttJn',
#   '1huvTbEYtgltjQRXzrNKGi',
#   '5maiP9UMnTSgoxPX8X3bdz',
#   '0rFke7eNFHbGuGJUdRgjB2',
#   '2aSC2xhRxOLiiZZVjhbylH',
#   '6K8qKeWo5MsFED7wCR6Kop',
#   '4G8gkOterJn0Ywt6uhqbhp',
#   '5G47DlluL671zo0k3OhoSm',
#   '13P5rwmk2EsoFRIz9UCeh9',
#   '4lhqb6JvbHId48OUJGwymk',
#   '1NklGBN7giNQzrUGtaUNwS',
#   '2bL2gyO6kBdLkNSkxXNh6x',
#   '5HJqpDspKDKwQpLjvkcIsD',
#   '03fT3OHB9KyMtGMt2zwqCT',
#   '3jVtllWS5CFFWLQng8sKsr',
#   '5CXnIPD6rTjszYYQm6fY2P',
#   '5BJSZocnCeSNeYMj3iVqM7',
#   '0HZUp8fm9fh1Mitqx4CIOr',
#   '3DmW6y7wTEYHJZlLo1r6XJ',
#   '1oew3nFNY3vMacJAsvry0S',
#   '6JEntXLt4z98CcDtIH9sU7',
#   '7DTlsMOQjGysXHpwwpHuPl',
#   '1dgWTMoHwTUnQhOQ8SR5fV',
#   '6Uy6K3KdmUdAfelUp0SeXn',
#   '2QjOHCTQ1Jl3zawyYOpxh6',
#   '3wx2kQWPn9p5UppQbNhPAk',
#   '3fBbfrWZUuWWrMQXFISr7N',
#   '5ChkMS8OtdzJeqyybCc9R5',
#   '1soxUgYIZb1qx1c7o1Lc7z',
#   '2xLOMHjkOK8nzxJ4r6yOKR',
#   '6olKv2HP3XgBpvVxAswowe',
#   '36pLU2ywVeBKEF0rrKtmCB',
#   '0n4bITAu0Y0nigrz3MFJMb',
#   '5XKXMWPACPq51OiqzxenZo',
#   '2Sh4sAOfnSHEVKFyysxzat',
#   '1JCCdiru7fhstOIF4N7WJC',
#   '38aECKrbMv2F5FsYYCewCQ',
#   '2kWowW0k4oFymhkr7LmvzO',
#   '6t2eIONH4Sax3R21QWiKNp',
#   '20FZrLl9zSbO9b3DhaqO6M',
#   '5dNGORzxFb5z3v7vSAFkTU',
#   '0CokSRCu5hZgPxcZBaEzVE',
#   '1gugDOSMREb34Xo0c1PlxM',
#   '2QtJA4gbwe1AcanB2p21aP',
#   '5hgnY0mVcVetszbb85qeDg',
#   '29gsi1zZrZxdStACmTQB0Z',
#   '4jtyUzZm9WLc2AdaJ1dso7',
#   '5aj0xPGiEUN3aI2oOYu14S',
#   '6s9m5J92By7jii22Q2XtY2',
#   '5AnCLGg35ziFOloEnXK4uu',
#   '32OlwWuMpZ6b0aN2RZOeMS',
#   '34gCuhDGsG4bRPIf9bb02f',
#   '2JzZzZUQj3Qff7wapcbKjc',
#   '2d8JP84HNLKhmd6IYOoupQ',
#   '2iuZJX9X9P0GKaE93xcPjk'],
#  ['4kbj5MwxO1bq9wjT5g9HaA',
#   '1p80LdxRV74UKvL8gnD7ky',
#   '5RIVoVdkDLEygELLCniZFr',
#   '4frLb7nWtsz2ymBE6k2GRP',
#   '7fBv7CLKzipRk6EC6TWHOB',
#   '023OVLNzXhX0j7CxswUt6D',
#   '22VdIZQfgXJea34mQxlt81',
#   '3zHq9ouUJQFQRf3cm1rRLu',
#   '1CS7Sd1u5tWkstBhpssyjP',
#   '273dCMFseLcVsoSWx59IoE',
#   '1Lim1Py7xBgbAkAys3AGAG',
#   '7oGZAicScQt96OAW4AruYy',
#   '5xTtaWoae3wi06K5WfVUUH',
#   '66hayvUbTotekKU3H4ta1f',
#   '37f4ITSlgPX81ad2EvmVQr',
#   '5NQbUaeTEOGdD6hHcre0dZ',
#   '6gj08XDlv9Duc2fPOxUmVD',
#   '41Fflg7qHiVOD6dEPvsCzO',
#   '0fgZUSa7D7aVvv3GfO0A1n',
#   '4MflGTO2ZTcSQ12bWcyRgI',
#   '7795WJLVKJoAyVoOtCWqXN',
#   '578Eooad7oUyn4stovZiPg',
#   '5jE48hhRu8E6zBDPRSkEq7',
#   '4lIxdJw6W3Fg4vUIYCB0S5',
#   '0wwPcA6wtMf6HUMpIRdeP7',
#   '5b2bu6yyATC1zMXDGScJ2d',
#   '6ebkx7Q5tTxrCxKq4GYj0Y',
#   '6xVXtFLsO3bq2ceu1HNIEA',
#   '1HNkqx9Ahdgi1Ixy2xkKkL',
#   '62PaSfnXSMyLshYJrlTuL3',
#   '7oQHjFgL4ijCGYcIOARZwE',
#   '2tpfxAXiI52znho4WE3XFA',
#   '5NQJnRpJHRaupdegphntQT',
#   '2bJvI42r8EF3wxjOuDav4r',
#   '7x5xYW5W42OGPAdHUyyguy',
#   '7ioiB40H9xKs04QtIso2I3',
#   '15JINEqzVMv3SvJTAXAKED',
#   '04aAxqtGp5pv12UXAg4pkq',
#   '1WoOzgvz6CgH4pX6a1RKGp',
#   '6DEaND0SHv3sC11xobZLiy',
#   '2bL2gyO6kBdLkNSkxXNh6x',
#   '7taXl2C2594pF4gjumrF4W',
#   '0NTMtAO2BV4tnGvw9EgBVq',
#   '4T0ScSPdQKmGvruK7pavNP',
#   '0PT7nlpo11hYYyfnBgtilT',
#   '4MRT0dDbhqFKl67WzhUbSw',
#   '5S9lfZu1YF8xKkgSsqL2Bd',
#   '2bbEGWoKmFG9h2JSt7qfg1',
#   '0fYVliAYKHuPmECRs1pbRf',
#   '7aXuop4Qambx5Oi3ynsKQr',
#   '37BZB0z9T8Xu7U3e65qxFy',
#   '59HjlYCeBsxdI0fcm3zglw',
#   '5Nm9ERjJZ5oyfXZTECKmRt',
#   '0lYBSQXN6rCTvUZvg9S0lU',
#   '5PUawWFG1oIS2NwEcyHaCr',
#   '02M6vucOvmRfMxTXDUwRXu',
#   '6wJwkMo278iWVlWl1XQ4WA',
#   '11qh54D0PKkBwelpDxxiEU',
#   '4NYwy0R3NdvORX2B6OZXBT',
#   '2K87XMYnUMqLcX3zvtAF4G',
#   '3keUgTGEoZJt0QkzTB6kHg',
#   '7xoUc6faLbCqZO6fQEYprd',
#   '5Eg4TsPcqNbIjd8ADMZosg',
#   '0hy1SOTEn9ifXTzOwnCwEr',
#   '4scpF6J5uMBvoh6sFB7EL1',
#   '3JvrhDOgAt6p7K8mDyZwRd',
#   '3G7XYAwtxtoGK7fAm4IlD9',
#   '70eDxAyAraNTiD6lx2ZEnH',
#   '3cU2wBxuV6nFiuf6PJZNlC',
#   '6ukMqDxnOPOgoHdak7Kyp3',
#   '2YlZnw2ikdb837oKMKjBkW',
#   '14OxJlLdcHNpgsm4DRwDOB',
#   '416MsJxvxSKY96DCmbJIRs',
#   '2JI71GHwq2LN8mtq3iCLYo',
#   '0puf9yIluy9W0vpMEUoAnN',
#   '64GRDrL1efgXclrhVCeuA0',
#   '2znzyzlAUc8Z1Ikq9aFOcx',
#   '4OjuzM3rTWp3q60mEldNSF',
#   '0CokSRCu5hZgPxcZBaEzVE',
#   '1TwLKNsCnhi1HxbIi4bAW0',
#   '1IIKrJVP1C9N7iPtG6eOsK',
#   '5g15o2Sm55Hn9ShK5yEXgp',
#   '1bzM1cd6oqFozdr4wK6HdR',
#   '2ixsaeFioXJmMgkkbd4uj1',
#   '2s1sdSqGcKxpPr5lCl7jAV',
#   '7FC9Lng8iXU081lbigu8m8',
#   '1huvTbEYtgltjQRXzrNKGi',
#   '4z7gh3aIZV9arbL9jJSc5J',
#   '1wYZZtamWTQAoj8B812uKQ',
#   '1HFfMOxCAT4GAwaPfCdmUs',
#   '2NA1oM7lrv3RPHxqmbwPfQ',
#   '7seTcUFOhn5caSDbiSfsp0',
#   '5O2P9iiztwhomNh8xkR9lJ',
#   '5lFDtgWsjRJu8fPOAyJIAK',
#   '6YUTL4dYpB9xZO5qExPf05',
#   '5Ge6envkioLfMEFTJj2RSg',
#   '7LHTSrftz5JfPuUPZDwZMh',
#   '1zi7xx7UVEFkmKfv06H8x0',
#   '72TFWvU3wUYdUuxejTTIzt',
#   '3CRDbSIZ4r5MsZ0YwxuEkn'],
#  ['275a9yzwGB6ncAW4SxY7q3',
#   '62PaSfnXSMyLshYJrlTuL3',
#   '1i1fxkWeaMmKEB4T7zqbzK',
#   '1WkMMavIMc4JZ8cfMmxHkI',
#   '7BKLCZ1jbUBVqRi2FVlTVw',
#   '3S4px9f4lceWdKf0gWciFu',
#   '5kqIPrATaCc2LqxVWzQGbk',
#   '4pAl7FkDMNBsjykPXo91B3',
#   '6Knv6wdA0luoMUuuoYi2i1',
#   '1MtUq6Wp1eQ8PC6BbPCj8P',
#   '4tCtwWceOPWzenK2HAIJSb',
#   '0azC730Exh71aQlOt9Zj3y',
#   '76hfruVvmfQbw0eYn1nmeC',
#   '1lPqDWq3Pucx3pMIZ8oXUM',
#   '2Z8WuEywRWYTKe1NybPQEW',
#   '6i0V12jOa3mr6uu4WYhUBr',
#   '0PDUDa38GO8lMxLCRc4lL1',
#   '7oQHjFgL4ijCGYcIOARZwE',
#   '0wwPcA6wtMf6HUMpIRdeP7',
#   '7zsXy7vlHdItvUSH8EwQss',
#   '0t7fVeEJxO2Xi4H2K5Svc9',
#   '3vv9phIu6Y1vX3jcqaGz5Z',
#   '3QGsuHI8jO1Rx4JWLUh9jd',
#   '3BtuIIrQlkujKPuWF2B85z',
#   '7EiZI6JVHllARrX9PUvAdX',
#   '6xVXtFLsO3bq2ceu1HNIEA',
#   '7fBv7CLKzipRk6EC6TWHOB',
#   '7K5dzhGda2vRTaAWYI3hrb',
#   '0qy5D3OJre7SPJNMOL9I71',
#   '3pXF1nA74528Edde4of9CC',
#   '6RUhbFEhrvGISaQ8u2j2JN',
#   '65OVbaJR5O1RmwOQx0875b',
#   '7vRriwrloYVaoAe3a9wJHe',
#   '1wYZZtamWTQAoj8B812uKQ',
#   '1BZG99C7Co1r6QUC3zaS59',
#   '3O8NlPh2LByMU9lSRSHedm',
#   '2YlZnw2ikdb837oKMKjBkW',
#   '7soJgKhQTO8hLP2JPRkL5O',
#   '13HVjjWUZFaWilh2QUJKsP',
#   '0l0CvurVUrr2w3Jj1hOVFc',
#   '6hmhG1b4LEyNuashVvuIAo',
#   '0lYBSQXN6rCTvUZvg9S0lU',
#   '27PmvZoffODNFW2p7ehZTQ',
#   '0BCy325UZyR9z0t0uxwn2N',
#   '37FXw5QGFN7uwwsLy8uAc0',
#   '63y6xWR4gXz7bnUGOk8iI6',
#   '6ZSO7kPn8IMJFymyticbJO',
#   '43PuMrRfbyyuz4QpZ3oAwN',
#   '5NQbUaeTEOGdD6hHcre0dZ',
#   '0PJIbOdMs3bd5AT8liULMQ',
#   '1LoriJC05IrHIDwj3q0KC1',
#   '0wdKiSBUT7aZkXUIdJWcwC',
#   '7MXVkk9YMctZqd1Srtv4MB',
#   '4JDZl9nKIAhAhDjw753u4X',
#   '5WI2ltQIdwgzf1SNE76JyR',
#   '25KybV9BOUlvcnv7nN3Pyo',
#   '3KwwE4sgCzMaKWq6QBebmX',
#   '70eDxAyAraNTiD6lx2ZEnH',
#   '5kNe7PE09d6Kvw5pAsx23n',
#   '6eT7xZZlB2mwyzJ2sUKG6w',
#   '3lSDIJ2abCrOdDJ6pshUap',
#   '7lGKEWMXVWWTt3X71Bv44I',
#   '1zPDgF3K6QXcTopDB3SVg9',
#   '1LxKKYsJNPeBdOwdudsJzv',
#   '16Ah4QqH4mgYVXqfC4mdSd',
#   '0lnIJmgcUpEpe4AZACjayW',
#   '22VdIZQfgXJea34mQxlt81',
#   '6nK6b39vhxL4sBTxKrykXC',
#   '2Gyc6e2cLxA5hoX1NOvYnU',
#   '1wHZx0LgzFHyeIZkUydNXq',
#   '4h0zU3O9R5xzuTmNO7dNDU',
#   '43bCmCI0nSgcT7QdMXY6LV',
#   '0EGuSSpuu9wmHCtvb4PdLO',
#   '59HjlYCeBsxdI0fcm3zglw',
#   '0g5EKLgdKvNlln7TNqBByK',
#   '5a7NdkF09AfD0H607eiOkX',
#   '5mPSyjLatqB00IkPqRlbTE',
#   '7GgWAITsYJaRM3r50rfh5w',
#   '0uyZ5ckiIUbFZd3P6RWmrj',
#   '1Lim1Py7xBgbAkAys3AGAG',
#   '2Z8yfpFX0ZMavHkcIeHiO1',
#   '5RIVoVdkDLEygELLCniZFr',
#   '6dlpABcXrQKRU9G00i6Zba',
#   '1CDBn2Lm7E63XKQDsdCq6O',
#   '376KnY4TrgBITxjlnbnmIy',
#   '10I3CmmwT0BkOVhduDy53o',
#   '7nD9nN3jord9wWcfW3Gkcm',
#   '5Gu0PDLN4YJeW75PpBSg9p',
#   '69uxyAqqPIsUyTO8txoP2M',
#   '4Pn0JlCUusD2QHjADuOzuV',
#   '6BbINUfGabVyiNFJpQXn3x',
#   '3NJG6vMH1ZsectZkocMEm0',
#   '2JzZzZUQj3Qff7wapcbKjc',
#   '3NLnwwAQbbFKcEcV8hDItk',
#   '7qiZfU4dY1lWllzX7mPBI3',
#   '6habFhsOp2NvshLv26DqMb',
#   '0KKkJNfGyhkQ5aFogxQAPU',
#   '7KXjTSCq5nL1LoYtL7XAwS',
#   '7BKLCZ1jbUBVqRi2FVlTVw',
#   '4Km5HrUvYTaSUfiSGPJeQR'],
#  ['7BKLCZ1jbUBVqRi2FVlTVw',
#   '7mldq42yDuxiUNn08nvzHO',
#   '0pqnGHJpmpxLKifKRmU6WP',
#   '3a1lNhkSLSkpJE4MSHpDu9',
#   '5uCax9HTNlzGybIStD3vDh',
#   '1jYiIOC5d6soxkJP81fxq2',
#   '7GX5flRQZVHRAGd6B4TmDO',
#   '0VgkVdmE4gld66l8iyGjgx',
#   '3B54sVLJ402zGa6Xm4YGNe',
#   '6b8Be6ljOzmkOmFslEb23P',
#   '09IStsImFySgyp0pIQdqAc',
#   '45XhKYRRkyeqoW3teSOkCM',
#   '6fujklziTHa8uoM5OQSfIo',
#   '7MXVkk9YMctZqd1Srtv4MB',
#   '152lZdxL1OR0ZMW6KquMif',
#   '5cF0dROlMOK5uNZtivgu50',
#   '7JJmb5XwzOO8jgpou264Ml',
#   '3g2qgbWPl8TcgJIkstWpSV',
#   '0wXuerDYiBnERgIpbb3JBR',
#   '2EEeOnHehOozLq4aS0n6SL',
#   '7vu0JkJh0ldukEYbTVcqd0',
#   '0prNGof3XqfTvNDxHonvdK',
#   '5tz69p7tJuGPeMGwNTxYuV',
#   '2cOUlop2ZakjOKe4WinesN',
#   '5oO3drDxtziYU2H1X23ZIp',
#   '3dhjNA0jGA8vHBQ1VdD6vV',
#   '0SGkqnVQo9KPytSri1H6cF',
#   '4Ro98RCK90oHqqSZUnTFq5',
#   '343YBumqHu19cGoGARUTsd',
#   '1nueTG77MzNkJTKQ0ZdGzT',
#   '1P17dC1amhFzptugyAO7Il',
#   '6PCUP3dWmTjcTtXY02oFdT',
#   '3XjqLgDutxuGWZlZU1yisE',
#   '15vzANxN8G9wWfwAJLLMCg',
#   '43bCmCI0nSgcT7QdMXY6LV',
#   '5knuzwU65gJK7IF5yJsuaW',
#   '6QgjcU0zLnzq5OrUoSZ3OK',
#   '0lYBSQXN6rCTvUZvg9S0lU',
#   '0yvPEnB032fojLfVluFjUv',
#   '2fQrGHiQOvpL9UgPvtYy6G',
#   '1WkMMavIMc4JZ8cfMmxHkI',
#   '0EhpEsp4L0oRGM0vmeaN5e',
#   '1zB4vmk8tFRmM9UULNzbLB',
#   '7KOlJ92bu51cltsD9KU5I7',
#   '4knL4iPxPOZjQzTUlELGSY',
#   '0AS63m1wHv9n4VVRizK6Hc',
#   '4Q3N4Ct4zCuIHuZ65E3BD4',
#   '0e7ipj03S05BNilyu5bRzt',
#   '10M2Ex445zw585Ducldzkw',
#   '6i0V12jOa3mr6uu4WYhUBr',
#   '7i2DJ88J7jQ8K7zqFX2fW8',
#   '5hTpBe8h35rJ67eAWHQsJx',
#   '0k6DnZMLoEUH8NGD5zh2SE',
#   '6HZILIRieu8S0iqY8kIKhj',
#   '1lItf5ZXJc1by9SbPeljFd',
#   '6mapJIPnQ23RTAevUoE0DL',
#   '5mCPDVBb16L4XQwDdbRUpz',
#   '6SwRhMLwNqEi6alNPVG00n',
#   '0jdny0dhgjUwoIp5GkqEaA',
#   '5uEYRdEIh9Bo4fpjDd4Na9',
#   '7gwLQ4tZ5UdZ7qNcDyJ8wr',
#   '0qy5D3OJre7SPJNMOL9I71',
#   '6gpcs5eMhJwax4mIfKDYQk',
#   '7zVCrzzEJU7u24sbJPXA5W',
#   '7qvxFz3JodM0A7xEM7k3YD',
#   '5bcTCxgc7xVfSaMV3RuVke',
#   '0SuLAslEMFZAXf0SwY7syi',
#   '6xHI9KjUjYT0FPtGO8Mxa1',
#   '3VlbOrM6nYPprVvzBZllE5',
#   '5Z3GHaZ6ec9bsiI5BenrbY',
#   '1e1JKLEDKP7hEQzJfNAgPl',
#   '0q75NwOoFiARAVp4EXU4Bs',
#   '1f5cbQtDrykjarZVrShaDI',
#   '5Gu0PDLN4YJeW75PpBSg9p',
#   '5tFep7dXGd7vEJ668wTPux',
#   '0Qh38w01QRXK6KHIv0e3hb',
#   '6kex4EBAj0WHXDKZMEJaaF',
#   '6p8NuHm8uCGnn2Dtbtf7zE',
#   '5Ohxk2dO5COHF1krpoPigN',
#   '4jL6WWKFDqCOPo2hC3VhSS',
#   '1UZOjK1BwmwWU14Erba9CZ',
#   '5eCkuGPZNl4mISFNPgr3Dd',
#   '5lNuqFVMca4vPupY10cH0J',
#   '3QGsuHI8jO1Rx4JWLUh9jd',
#   '1XRgIKC5TPwo7nWGyKqgG0',
#   '2YMhrXQYKkm4kXLcXKKd5z',
#   '3J8Q6aBhjpvao8BsBQ6H9Y',
#   '1rfofaqEpACxVEHIZBJe6W',
#   '2j5hsQvApottzvTn4pFJWF',
#   '3Q3myFA7q4Op95DOpHplaY',
#   '7floNISpH8VF4z4459Qo18',
#   '5OUSPcqhYTOzpbXzoEvKim',
#   '6DCZcSspjsKoFjzjrWoCdn',
#   '0tgVpDi06FyKpA1z0VMD4v',
#   '7iDa6hUg2VgEL1o1HjmfBn',
#   '1rfofaqEpACxVEHIZBJe6W',
#   '0e7ipj03S05BNilyu5bRzt',
#   '3swc6WTsr7rl9DqQKQA55C',
#   '58q2HKrzhC3ozto2nDdN4z',
#   '09IStsImFySgyp0pIQdqAc'],
#  ['2G7V7zsVDxg1yRsu7Ew9RJ',
#   '4wGL1r23K9zYEDYxfuSwSQ',
#   '3CA9pLiwRIGtUBiMjbZmRw',
#   '285pBltuF7vW8TeWk8hdRR',
#   '7dt6x5M1jzdTEt8oCbisTK',
#   '7MAibcTli4IisCtbHKrGMh',
#   '0At2qAoaVjIwWNAqrscXli',
#   '2ekn2ttSfGqwhhate0LSR0',
#   '3ee8Jmje8o58CHK66QrVC2',
#   '4eWQlBRaTjPPUlzacqEeoQ',
#   '0u2P5u6lvoDfwTYjAADbn4',
#   '2qT1uLXPVPzGgFOx4jtEuo',
#   '7uzmGiiJyRfuViKKK3lVmR',
#   '1zB4vmk8tFRmM9UULNzbLB',
#   '4qKcDkK6siZ7Jp1Jb4m0aL',
#   '6NFyWDv5CjfwuzoCkw47Xf',
#   '65OVbaJR5O1RmwOQx0875b',
#   '2Y0wPrPQBrGhoLn14xRYCG',
#   '7y9iMe8SOB6z3NoHE2OfXl',
#   '5IaHrVsrferBYDm0bDyABy',
#   '52okn5MNA47tk87PeZJLEL',
#   '2DQ1ITjI0YoLFzuADN1ZBW',
#   '2l8nEO0vsTRCRnGqQty6qx',
#   '42fw0rxRO2xbesF6mJfd4Y',
#   '6QgjcU0zLnzq5OrUoSZ3OK',
#   '4wFjTWCunQFKtukqrNijEt',
#   '2P91MQbaiQOfbiz9VqhqKQ',
#   '2iUXsYOEPhVqEBwsqP70rE',
#   '6Qn5zhYkTa37e91HC1D7lb',
#   '1dg3qy5DjoJodawfOCgrTP',
#   '75ZvA4QfFiZvzhj2xkaWAh',
#   '37BZB0z9T8Xu7U3e65qxFy',
#   '4hQ6UGyWQIGJmHSo0J88JW',
#   '2xLMifQCjDGFmkHkpNLD9h',
#   '6n4U3TlzUGhdSFbUUhTvLP',
#   '43ZyHQITOjhciSUUNPVRHc',
#   '1NawUUW8GmiRbJ9UkaKGY4',
#   '2QZ7WLBE8h2y1Y5Fb8RYbH',
#   '7KXjTSCq5nL1LoYtL7XAwS',
#   '2UVbBKQOdFAekPTRsnkzcf',
#   '3VlbOrM6nYPprVvzBZllE5',
#   '6PGoSes0D9eUDeeAafB2As',
#   '0b9oOr2ZgvyQu88wzixux9',
#   '0TlLq3lA83rQOYtrqBqSct',
#   '1HXy5I3HTWq8OvxCn0z7G7',
#   '3g2qgbWPl8TcgJIkstWpSV',
#   '10Igtw8bSDyyFs7KIsKngZ',
#   '4HbiCvH1R7mVOJ7KY7JQBD',
#   '1ZAyjvIk9YiD76yYy0TEG6',
#   '6AvfZXpbb6r35DfF7gHPRq',
#   '2jGVn73c7vUmHmtdxg7zvx',
#   '0dIoGTQXDh1wVnhIiSyYEa',
#   '5OCJzvD7sykQEKHH7qAC3C',
#   '0ZNrc4kNeQYD9koZ3KvCsy',
#   '0yvPEnB032fojLfVluFjUv',
#   '6wmAHw1szh5RCKSRjiXhPe',
#   '5A6BJLZArq1MPjsnmcuk5f',
#   '5Z3GHaZ6ec9bsiI5BenrbY',
#   '6YUTL4dYpB9xZO5qExPf05',
#   '2FY7b99s15jUprqC0M5NCT',
#   '6EGAfJaLUFzhS4zRBIEQ2J',
#   '7qiZfU4dY1lWllzX7mPBI3',
#   '1XRgIKC5TPwo7nWGyKqgG0',
#   '5WvAo7DNuPRmk4APhdPzi8',
#   '4dVpf9jZjcORqGTLUaeYj9',
#   '5WoaF1B5XIEnWfmb5NZikf',
#   '0OWZFobGSIW9GrSlQ9C5pc',
#   '0d2iYfpKoM0QCKvcLCkBao',
#   '09mEdoA6zrmBPgTEN5qXmN',
#   '51rXHuKN8Loc4sUlKPODgH',
#   '2Y0wPrPQBrGhoLn14xRYCG',
#   '3V8UKqhEK5zBkBb6d6ub8i',
#   '4L9Ds4mpD3SuYoWwFUlv16',
#   '4PpuH4mxL0rD35mOWaLoKS',
#   '5tz69p7tJuGPeMGwNTxYuV',
#   '09ts3GnICqYEU5PkQCpJK3',
#   '3qN5qMTKyEEmiTZD38BNTT',
#   '6n6OQfBpCgzF9oEg8zhBN7',
#   '0JP9xo3adEtGSdUEISiszL',
#   '2j5hsQvApottzvTn4pFJWF',
#   '5YUyW9opqNsMSEzzecZih1',
#   '3sA7HKGzcKTVscdiTCrWpX',
#   '6CTWathupIiDs7U4InHnDA',
#   '3vo8ohog12NMuae4pBcfdp',
#   '7AFASza1mXqntmGtbxXprO',
#   '2VIPU72L6tIR4w8J8ap6Kp',
#   '4gB7HrYHbJVJ5RFOjxmoq4',
#   '1Ser4X0TKttOvo8bgdytTP',
#   '76cy1WJvNGJTj78UqeA5zr',
#   '0EhpEsp4L0oRGM0vmeaN5e',
#   '0pqnGHJpmpxLKifKRmU6WP',
#   '2YpeDb67231RjR0MgVLzsG',
#   '21jGcNKet2qwijlDFuPiPb',
#   '5p7ujcrUXASCNwRaWNHR1C',
#   '2Fxmhks0bxGSBdJ92vM42m',
#   '7xQAfvXzm3AkraOtGPWIZg',
#   '2Y0wPrPQBrGhoLn14xRYCG',
#   '6ocbgoVGwYJhOv1GgI9NsF',
#   '7bXa3y0BltUsWkmpRg6gOu',
#   '2xLMifQCjDGFmkHkpNLD9h'],
#  ['22vgEDb5hykfaTwLuskFGD',
#   '1rqqCSm0Qe4I9rUvWncaom',
#   '3e9HZxeyfWwjeyPAMmWSSQ',
#   '3HWzoMvoF3TQfYg4UPszDq',
#   '5Nm9ERjJZ5oyfXZTECKmRt',
#   '2Z8yfpFX0ZMavHkcIeHiO1',
#   '0tgVpDi06FyKpA1z0VMD4v',
#   '0d2iYfpKoM0QCKvcLCkBao',
#   '2IRZnDFmlqMuOrYOLnZZyc',
#   '0SiywuOBRcynK0uKGWdCnn',
#   '6zeeWid2sgw4lap2jV61PZ',
#   '6XHVuErjQ4XNm6nDPVCxVX',
#   '4wGL1r23K9zYEDYxfuSwSQ',
#   '7DnAm9FOTWE3cUvso43HhI',
#   '2gwkD6igEhQbDQegRCcdoB',
#   '2JvzF1RMd7lE3KmFlsyZD8',
#   '65OVbaJR5O1RmwOQx0875b',
#   '7qEHsqek33rTcFNT9PFqLf',
#   '6FtLdyJpVlBBhTuqy9LaQj',
#   '0t3ZvGKlmYmVsDzBJAXK8C',
#   '0FZ4Dmg8jJJAPJnvBIzD9z',
#   '7dt6x5M1jzdTEt8oCbisTK',
#   '2iUXsYOEPhVqEBwsqP70rE',
#   '5ry2OE6R2zPQFDO85XkgRb',
#   '3GJ4hzg4lrGwU51Y3VARbF',
#   '4kV4N9D1iKVxx1KLvtTpjS',
#   '1XXimziG1uhM0eDNCZCrUl',
#   '2GGMabyHXnJmjY6CXhhB2e',
#   '6RRNNciQGZEXnqk8SQ9yv5',
#   '4SDgTLDYrJ2UrHbkRkg7MD',
#   '3Ol2xnObFdKV9pmRD2t9x8',
#   '2t8yVaLvJ0RenpXUIAC52d',
#   '2Rk4JlNc2TPmZe2af99d45',
#   '116H0KvKr2Zl4RPuVBruDO',
#   '6uFn47ACjqYkc0jADwEdj1',
#   '2rxQMGVafnNaRaXlRMWPde',
#   '5GBuCHuPKx6UC7VsSPK0t3',
#   '285pBltuF7vW8TeWk8hdRR',
#   '1xzBco0xcoJEDXktl7Jxrr',
#   '4evmHXcjt3bTUHD1cvny97',
#   '6foY66mWZN0pSRjZ408c00',
#   '1dyxS3YzBbL0t8rEVwVQ1K',
#   '3EPXxR3ImUwfayaurPi3cm',
#   '3QzAOrNlsabgbMwlZt7TAY',
#   '2KKijf6Ett4kmVNJze2roh',
#   '4w8niZpiMy6qz1mntFA5uM',
#   '7rvyVWja33WG9R97oeJAjx',
#   '6Up545NUflOiXo8cEraH49',
#   '22oEJW6r2rMb9z4IntfyEa',
#   '21jGcNKet2qwijlDFuPiPb',
#   '7aEtlGHoiPAfRB084NiDmx',
#   '7DcvwMAiqKJQD1rrdfxSDx',
#   '35UUpTmrcFXNIVIN26ujXl',
#   '7eBqSVxrzQZtK2mmgRG6lC',
#   '43zdsphuZLzwA9k4DJhU0I',
#   '3A2yGHWIzmGEIolwonU69h',
#   '58q2HKrzhC3ozto2nDdN4z',
#   '0lsRatBUs9HNIZAmoGABzk',
#   '6V7g6qM8wheMivMWrzbPTM',
#   '4OafepJy2teCjYJbvFE60J',
#   '4SSnFejRGlZikf02HLewEF',
#   '5nzhL67GpF9szXWg5y509A',
#   '5ygDXis42ncn6kYG14lEVG',
#   '5KBARWIxeMGkvUax9VtVC9',
#   '0PQoUlzP7ILdcrzpajHXc0',
#   '0DiDStADDVh3SvAsoJAFMk',
#   '6ERR6e7h6wCqGoz1TjiUJb',
#   '6CTWathupIiDs7U4InHnDA',
#   '56eGOeSsqdg3FLxdo83TwV',
#   '1wJRveJZLSb1rjhnUHQiv6',
#   '6b2RcmUt1g9N9mQ3CbjX2Y',
#   '65OVbaJR5O1RmwOQx0875b',
#   '2KqJC0koTBUyDlsMt5ok1V',
#   '19kUPdKTp85q9RZNwaXM15',
#   '59ywHNwwchG4nZJMLyxSzd',
#   '0u2P5u6lvoDfwTYjAADbn4',
#   '2Y0wPrPQBrGhoLn14xRYCG',
#   '2rMAtCaTj16NptyVfEIeAC',
#   '42fw0rxRO2xbesF6mJfd4Y',
#   '67XyC1GdSkKb9sbRRkUDXS',
#   '5N1o6d8zGcSZSeMFkOUQOk',
#   '4qQwGRtGT7l6ckQtdPEFd4',
#   '4VUwkH455At9kENOfzTqmF',
#   '5AnSllIrgGsCZzZJkVnApx',
#   '08tq1XcHwVt5PHXUo87i0D',
#   '37BZB0z9T8Xu7U3e65qxFy',
#   '1E9j4yItxiPrSbcLmo8IaN',
#   '6Hj9jySrnFppAI0sEMCZpJ']]

# %%
test = chunks[13]

# %%
test = spotify.audio_features(tracks=test) #test

# %%
type(test[0])
pd.DataFrame(spotify.audio_features(tracks=))
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.748   0.524    8    -5.599     1       0.0338        0.4140
# 1          0.732   0.458    5    -7.225     1       0.0311        0.4470
# 2          0.776   0.780   10    -4.374     0       0.1280        0.0622
# 3          0.630   0.804    6    -4.183     1       0.0363        0.2150
# 4          0.358   0.557   10    -7.398     1       0.0590        0.6950
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.765   0.523    2    -4.333     1       0.0300        0.1840
# 96         0.585   0.520    5    -6.136     0       0.0712        0.1240
# 97         0.750   0.560    8    -8.094     1       0.1050        0.5460
# 98         0.816   0.726    5    -3.998     0       0.1290        0.0990
# 99         0.753   0.657    7    -3.061     1       0.0449        0.1710
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.1110    0.661   95.010  audio_features
# 1           0.000000    0.1360    0.661   98.938  audio_features
# 2           0.000000    0.0810    0.666  124.949  audio_features
# 3           0.000000    0.2530    0.492  123.146  audio_features
# 4           0.000000    0.0902    0.494   85.043  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000036    0.1320    0.394  104.988  audio_features
# 96          0.000070    0.1310    0.129  159.801  audio_features
# 97          0.000000    0.1110    0.459  140.060  audio_features
# 98          0.000000    0.3720    0.650  136.048  audio_features
# 99          0.000000    0.1120    0.437  107.010  audio_features
#
#                         id                                   uri  \
# 0   7BKLCZ1jbUBVqRi2FVlTVw  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 1   7mldq42yDuxiUNn08nvzHO  spotify:track:7mldq42yDuxiUNn08nvzHO
# 2   0pqnGHJpmpxLKifKRmU6WP  spotify:track:0pqnGHJpmpxLKifKRmU6WP
# 3   3a1lNhkSLSkpJE4MSHpDu9  spotify:track:3a1lNhkSLSkpJE4MSHpDu9
# 4   5uCax9HTNlzGybIStD3vDh  spotify:track:5uCax9HTNlzGybIStD3vDh
# ..                     ...                                   ...
# 95  1rfofaqEpACxVEHIZBJe6W  spotify:track:1rfofaqEpACxVEHIZBJe6W
# 96  0e7ipj03S05BNilyu5bRzt  spotify:track:0e7ipj03S05BNilyu5bRzt
# 97  3swc6WTsr7rl9DqQKQA55C  spotify:track:3swc6WTsr7rl9DqQKQA55C
# 98  58q2HKrzhC3ozto2nDdN4z  spotify:track:58q2HKrzhC3ozto2nDdN4z
# 99  09IStsImFySgyp0pIQdqAc  spotify:track:09IStsImFySgyp0pIQdqAc
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/7BKLCZ1jbUBV...
# 1   https://api.spotify.com/v1/tracks/7mldq42yDuxi...
# 2   https://api.spotify.com/v1/tracks/0pqnGHJpmpxL...
# 3   https://api.spotify.com/v1/tracks/3a1lNhkSLSkp...
# 4   https://api.spotify.com/v1/tracks/5uCax9HTNlzG...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/1rfofaqEpACx...
# 96  https://api.spotify.com/v1/tracks/0e7ipj03S05B...
# 97  https://api.spotify.com/v1/tracks/3swc6WTsr7rl...
# 98  https://api.spotify.com/v1/tracks/58q2HKrzhC3o...
# 99  https://api.spotify.com/v1/tracks/09IStsImFySg...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/7BKL...       244960
# 1   https://api.spotify.com/v1/audio-analysis/7mld...       165387
# 2   https://api.spotify.com/v1/audio-analysis/0pqn...       204347
# 3   https://api.spotify.com/v1/audio-analysis/3a1l...       220293
# 4   https://api.spotify.com/v1/audio-analysis/5uCa...       211467
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/1rfo...       217307
# 96  https://api.spotify.com/v1/audio-analysis/0e7i...       218147
# 97  https://api.spotify.com/v1/audio-analysis/3swc...       221440
# 98  https://api.spotify.com/v1/audio-analysis/58q2...       253390
# 99  https://api.spotify.com/v1/audio-analysis/09IS...       184732
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
x = []

for i in range(12,14):
    a = spotify.audio_features(tracks=chunks[i])
    x.append(a)

# %%
y= [] 

for i in range(0,len(x)):
    b = x[i]
    y.append(b)

# %%
type(x[0][1])
# Out:
# dict

# %%
pd.json_normalize(x,record_path='counties', meta=['state', 'shortname', ['info', 'governor']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-29027290bceb> in <module>
#       1 for i in range(0,len(x)):
# ----> 2     pd.json_normalize(x[i])
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     276             # TODO: handle record value which are lists, at least error
#     277             #       reasonably
# --> 278             data = nested_to_record(data, sep=sep, max_level=max_level)
#     279         return DataFrame(data)
#     280     elif not isinstance(record_path, list):
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in nested_to_record(ds, prefix, sep, level, max_level)
#      80     for d in ds:
#      81         new_d = copy.deepcopy(d)
# ---> 82         for k, v in d.items():
#      83             # each key gets renamed with prefix
#      84             if not isinstance(k, str):
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
past_audio_features = pd.DataFrame()

for i in range(0,len(chunks)):
    p = pd.DataFrame(spotify.audio_features(tracks=chunks[i]))
    past_audio_features.append(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-181-faa48a577121> in <module>
#       2
#       3 for i in range(0,len(chunks)):
# ----> 4     p = pd.DataFrame(spotify.audio_features(tracks=chunks[i]))
#       5     past_audio_features.append(p)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
# --> 530         return _list_of_dict_to_arrays(
#     531             data, columns, coerce_float=coerce_float, dtype=dtype
#     532         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#     641         gen = (list(x.keys()) for x in data)
#     642         sort = not any(isinstance(d, dict) for d in data)
# --> 643         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     644
#     645     # assure that they are of the base dict class and not of derived
#
# pandas\_libs\lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in <genexpr>(.0)
#     639     """
#     640     if columns is None:
# --> 641         gen = (list(x.keys()) for x in data)
#     642         sort = not any(isinstance(d, dict) for d in data)
#     643         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
len(chunks)
# Out:
# 14
